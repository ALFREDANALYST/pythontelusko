# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:\Downloads\lightning_strikes.csv")
df.head()
# Out:
#                 date  number_of_strikes   center_point_geom
# 0         2016-08-05                 16  POINT(-101.5 24.7)
# 1         2016-08-05                 16     POINT(-85 34.3)
# 2         2016-08-05                 16     POINT(-89 41.4)
# 3         2016-08-05                 16   POINT(-89.8 30.7)
# 4         2016-08-05                 16   POINT(-86.2 37.9)
# ...              ...                ...                 ...
# 10478998  2018-05-27                 13    POINT(-111.3 41)
# 10478999  2018-05-27                 13  POINT(-109.4 43.4)
# 10479000  2018-05-27                 13    POINT(-104.2 50)
# 10479001  2018-05-27                 13   POINT(-88.7 36.4)
# 10479002  2018-05-27                 13   POINT(-87.1 44.9)
#
# [10479003 rows x 3 columns]

# %%
df.shape
# Out:
# (10479003, 3)

# %%
df2 = pd.read_csv("D:\Downloads\lightning_strikes2.csv")
df2.head()
# Out:
#          date  zip_code                                 city          state  \
# 0  2018-08-08      3281                                Weare  New Hampshire
# 1  2018-08-14      6488                 Heritage Village CDP    Connecticut
# 2  2018-08-16     97759  Sisters city, Black Butte Ranch CDP         Oregon
# 3  2018-08-18      6776                      New Milford CDP    Connecticut
# 4  2018-08-08      1077                            Southwick  Massachusetts
#
#   state_code   center_point_geom  number_of_strikes
# 0         NH   POINT(-71.7 43.1)                  1
# 1         CT   POINT(-73.2 41.5)                  3
# 2         OR  POINT(-121.4 44.3)                  3
# 3         CT   POINT(-73.4 41.6)                 48
# 4         MA     POINT(-72.8 42)                  2

# %%
df2.shape
# Out:
# (323700, 7)

# %%
df_joined = df.merge(df2, how = 'left', on = ['date','center_point_geom'])
df_joined.head()
# Out:
#          date  number_of_strikes_x   center_point_geom  zip_code city state  \
# 0  2016-08-05                   16  POINT(-101.5 24.7)       NaN  NaN   NaN
# 1  2016-08-05                   16     POINT(-85 34.3)       NaN  NaN   NaN
# 2  2016-08-05                   16     POINT(-89 41.4)       NaN  NaN   NaN
# 3  2016-08-05                   16   POINT(-89.8 30.7)       NaN  NaN   NaN
# 4  2016-08-05                   16   POINT(-86.2 37.9)       NaN  NaN   NaN
#
#   state_code  number_of_strikes_y
# 0        NaN                  NaN
# 1        NaN                  NaN
# 2        NaN                  NaN
# 3        NaN                  NaN
# 4        NaN                  NaN

# %%
df_joined.describe()
# Out:
#        number_of_strikes_x       zip_code  number_of_strikes_y
# count         1.047900e+07  323700.000000        323700.000000
# mean          1.157347e+01   57931.958996            25.410587
# std           2.788072e+01   22277.327411            57.421824
# min           1.000000e+00    1002.000000             1.000000
# 25%           1.000000e+00   38260.750000             3.000000
# 50%           3.000000e+00   59212.500000             8.000000
# 75%           1.000000e+01   78642.000000            24.000000
# max           2.386000e+03   99402.000000          2211.000000

# %%
df_joined.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10479003 entries, 0 to 10479002
# Data columns (total 8 columns):
#  #   Column               Non-Null Count     Dtype
# ---  ------               --------------     -----
#  0   date                 10479003 non-null  object
#  1   number_of_strikes_x  10479003 non-null  int64
#  2   center_point_geom    10479003 non-null  object
#  3   zip_code             323700 non-null    float64
#  4   city                 323700 non-null    object
#  5   state                323700 non-null    object
#  6   state_code           323700 non-null    object
#  7   number_of_strikes_y  323700 non-null    float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 639.6+ MB

# %%
# Create a new df of just the rows that are missing data
df_null_geo = df_joined[pd.isnull(df_joined.state_code)]
df_null_geo.shape
# Out:
# (10155303, 8)

# %%
df_null_geo.head()
# Out:
#          date  number_of_strikes_x   center_point_geom  zip_code city state  \
# 0  2016-08-05                   16  POINT(-101.5 24.7)       NaN  NaN   NaN
# 1  2016-08-05                   16     POINT(-85 34.3)       NaN  NaN   NaN
# 2  2016-08-05                   16     POINT(-89 41.4)       NaN  NaN   NaN
# 3  2016-08-05                   16   POINT(-89.8 30.7)       NaN  NaN   NaN
# 4  2016-08-05                   16   POINT(-86.2 37.9)       NaN  NaN   NaN
#
#   state_code  number_of_strikes_y
# 0        NaN                  NaN
# 1        NaN                  NaN
# 2        NaN                  NaN
# 3        NaN                  NaN
# 4        NaN                  NaN

# %%
# Create new df of just latitude, longitude, and number of strikes and group by latitude and longitude
top_missing = df_null_geo[['center_point_geom','number_of_strikes_x']
            ].groupby(['center_point_geom']
                      ).sum().sort_values('number_of_strikes_x',ascending=False).reset_index()
top_missing.head(10)
# Out:
#    center_point_geom  number_of_strikes_x
# 0  POINT(-84.2 22.4)                11134
# 1  POINT(-82.3 22.9)                 9457
# 2  POINT(-82.2 22.9)                 9439
# 3  POINT(-84.1 22.5)                 9246
# 4  POINT(-84.1 22.4)                 9173
# 5  POINT(-84.2 22.3)                 9153
# 6  POINT(-82.4 22.9)                 9142
# 7  POINT(-82.5 22.9)                 8983
# 8  POINT(-82.3 22.8)                 8952
# 9  POINT(-84.3 22.3)                 8721

# %%
# Extract longitude and latitude from the POINT string
import re
def parse_point(point_str):
    match = re.match(r'POINT\(([-\d.]+)\s+([-\d.]+)\)', point_str)
    lon, lat = float(match.group(1)), float(match.group(2))
    return pd.Series({'lon': lon, 'lat': lat})

top_missing[['lon', 'lat']] = top_missing['center_point_geom'].apply(parse_point)
top_missing.head()
# Out:
#    center_point_geom  number_of_strikes_x   lon   lat
# 0  POINT(-84.2 22.4)                11134 -84.2  22.4
# 1  POINT(-82.3 22.9)                 9457 -82.3  22.9
# 2  POINT(-82.2 22.9)                 9439 -82.2  22.9
# 3  POINT(-84.1 22.5)                 9246 -84.1  22.5
# 4  POINT(-84.1 22.4)                 9173 -84.1  22.4

# %%
import plotly.express as px  # Be sure to import express
# reduce size of db otherwise it could break
fig = px.scatter_geo(top_missing[top_missing.number_of_strikes_x>=300],  # Input Pandas DataFrame
                    lat="lat",  # DataFrame column with latitude
                    lon="lon",  # DataFrame column with latitude
                    size="number_of_strikes_x") # Set to plot size as number of strikes
fig.update_layout(
    title_text = 'Missing data', # Create a Title
)

fig.show()
