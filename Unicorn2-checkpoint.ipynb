# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
companies = pd.read_csv("D:/Downloads/Unicorn_Companies.csv")
companies.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B      4/7/17              Artificial intelligence
# 1        SpaceX     $100B     12/1/12                                Other
# 2         SHEIN     $100B      7/3/18      E-commerce & direct-to-consumer
# 3        Stripe      $95B     1/23/14                              Fintech
# 4        Klarna      $46B    12/12/11                              Fintech
# 5         Canva      $40B      1/8/18         Internet software & services
# 6  Checkout.com      $40B      5/2/19                              Fintech
# 7     Instacart      $39B    12/30/14  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B    12/20/17                    Consumer & retail
# 9    Databricks      $38B      2/5/19          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# ...

# %%
companies.shape
# Out:
# (1074, 10)

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   object
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
#  9   Select Investors  1073 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 84.0+ KB

# %%
# Check for duplicates.
companies.drop_duplicates()
# Out:
#           Company Valuation Date Joined                         Industry  \
# 0       Bytedance     $180B      4/7/17          Artificial intelligence
# 1          SpaceX     $100B     12/1/12                            Other
# 2           SHEIN     $100B      7/3/18  E-commerce & direct-to-consumer
# 3          Stripe      $95B     1/23/14                          Fintech
# 4          Klarna      $46B    12/12/11                          Fintech
# ...           ...       ...         ...                              ...
# 1069     Zhaogang       $1B     6/29/17  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan       $1B     4/18/17  E-commerce & direct-to-consumer
# 1071     Zihaiguo       $1B      5/6/21                Consumer & retail
# 1072         Zopa       $1B    10/19/21                          Fintech
# 1073        Zwift       $1B     9/16/20  E-commerce & direct-to-consumer
#
#                City  Country/Region      Continent  Year Founded Funding  \
# ...

# %%
# Sort `companies` and display the first 10 rows of the resulting DataFrame.

### YOUR CODE HERE ###
companies.sort_values('Year Founded',ascending =False).head(10)
# Out:
#             Company Valuation Date Joined                         Industry  \
# 782         Phantom       $1B     1/31/22                          Fintech
# 714    Yidian Zixun       $1B    10/17/17      Mobile & telecommunications
# 822      GlobalBees       $1B    12/28/21  E-commerce & direct-to-consumer
# 554      ClickHouse       $2B    10/28/21      Data management & analytics
# 952  LayerZero Labs       $1B     3/30/22     Internet software & services
# 314      Flink Food       $3B     12/1/21  E-commerce & direct-to-consumer
# 864           Aptos       $1B     3/15/22     Internet software & services
# 238       Yuga Labs       $4B     3/22/22                          Fintech
# 775            Jokr       $1B     12/2/21  E-commerce & direct-to-consumer
# 967    Mensa Brands       $1B    11/16/21                            Other
#
#                City Country/Region      Continent  Year Founded Funding  \
# ...

# %%
# Display each unique year that occurs in the dataset
# along with the number of companies that were founded in each unique year.

### YOUR CODE HERE ###
companies.groupby('Year Founded')['Company'].count()
# Out:
# Year Founded
# 1919      1
# 1979      1
# 1984      1
# 1990      1
# 1991      1
# 1992      1
# 1993      1
# 1994      2
# 1995      2
# 1996      1
# 1997      1
# 1998      5
# 1999      8
# 2000     11
# 2001      9
# 2002      4
# 2003      8
# 2004      8
# 2005     14
# 2006     15
# 2007     24
# 2008     27
# 2009     34
# 2010     40
# 2011     82
# 2012     95
# 2013     87
# 2014    109
# 2015    155
# 2016    110
# 2017     74
# 2018     61
# 2019     45
# 2020     25
# 2021     11
# Name: Company, dtype: int64

# %%
# Plot a histogram of the Year Founded feature.
### YOUR CODE HERE ###
companies['Year Founded'].hist()
# Out:
# <Axes: >

# %%
# Plot a histogram of the Year Founded feature.
### YOUR CODE HERE ###
plt.hist(companies['Year Founded'], bins=range(1920, 2020,5))
plt.ylabel('companies founded')
plt.xlabel('Year Founded')
plt.title('Years and Companies founded')
plt.show();

# %%
# Convert the `Date Joined` column to datetime.
# Update the column with the converted values.

### YOUR CODE HERE ###

companies['Date Joined'] = pd.to_datetime(companies['Date Joined'])


# Display the data types of the columns in `companies`
# to confirm that the update actually took place.

### YOUR CODE HERE ###

companies.info()
# Out:
# C:\Users\MBOGO ALFRED\AppData\Local\Temp\ipykernel_26576\3578071966.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   companies['Date Joined'] = pd.to_datetime(companies['Date Joined'])
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1074 entries, 0 to 1073
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1074 non-null   object
#  1   Valuation         1074 non-null   object
#  2   Date Joined       1074 non-null   datetime64[ns]
#  3   Industry          1074 non-null   object
#  4   City              1058 non-null   object
#  5   Country/Region    1074 non-null   object
#  6   Continent         1074 non-null   object
#  7   Year Founded      1074 non-null   int64
#  8   Funding           1074 non-null   object
# ...

# %%
# Obtain the names of the months when companies gained unicorn status.
# Use the result to create a `Month Joined` column.

### YOUR CODE HERE ###
companies['Month Joined'] = companies['Date Joined'].dt.month_name()
companies['weekday'] = companies['Date Joined'].dt.day_name()
companies['Year'] = companies['Date Joined'].dt.year


# Display the first few rows of `companies`
# to confirm that the new column did get added.

### YOUR CODE HERE ###
companies.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B  2017-04-07              Artificial intelligence
# 1        SpaceX     $100B  2012-12-01                                Other
# 2         SHEIN     $100B  2018-07-03      E-commerce & direct-to-consumer
# 3        Stripe      $95B  2014-01-23                              Fintech
# 4        Klarna      $46B  2011-12-12                              Fintech
# 5         Canva      $40B  2018-01-08         Internet software & services
# 6  Checkout.com      $40B  2019-05-02                              Fintech
# 7     Instacart      $39B  2014-12-30  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B  2017-12-20                    Consumer & retail
# 9    Databricks      $38B  2019-02-05          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# ...

# %%
# Determine how many years it took for companies to reach unicorn status.
# Use the result to create a `Years To Join` column.

### YOUR CODE HERE ###


# Calculate years to reach unicorn status
companies['Years_To_Join'] = companies['Year'] - companies['Year Founded']
# Display the first few rows of `companies`
# to confirm that the new column did get added.

### YOUR CODE HERE ###
companies.head(10)
# Out:
#         Company Valuation Date Joined                             Industry  \
# 0     Bytedance     $180B  2017-04-07              Artificial intelligence
# 1        SpaceX     $100B  2012-12-01                                Other
# 2         SHEIN     $100B  2018-07-03      E-commerce & direct-to-consumer
# 3        Stripe      $95B  2014-01-23                              Fintech
# 4        Klarna      $46B  2011-12-12                              Fintech
# 5         Canva      $40B  2018-01-08         Internet software & services
# 6  Checkout.com      $40B  2019-05-02                              Fintech
# 7     Instacart      $39B  2014-12-30  Supply chain, logistics, & delivery
# 8     JUUL Labs      $38B  2017-12-20                    Consumer & retail
# 9    Databricks      $38B  2019-02-05          Data management & analytics
#
#             City  Country/Region      Continent  Year Founded Funding  \
# 0        Beijing           China           Asia          2012     $8B
# ...

# %%
# Filter dataset by a year of your interest (in terms of when companies reached unicorn status).
# Save the resulting subset in a new variable. 

### YOUR CODE HERE ###


companies_2015 = companies[companies['Year'] == 2015]

# Display the first few rows of the subset to confirm that it was created.

### YOUR CODE HERE ###

companies_2015.head(10)
# Out:
#                 Company Valuation Date Joined  \
# 55                Gusto      $10B  2015-12-18
# 70               Tanium       $9B  2015-03-31
# 72      DJI Innovations       $8B  2015-01-23
# 104            WeDoctor       $6B  2015-09-22
# 133  Royole Corporation       $5B  2015-08-18
# 246               Yixia       $3B  2015-11-24
# 299             Illumio       $3B  2015-04-14
# 310           Thumbtack       $3B  2015-09-29
# 374          Tubatu.com       $2B  2015-03-09
# 385           AppDirect       $2B  2015-10-07
#
#                             Industry           City Country/Region  \
# 55                           Fintech  San Francisco  United States
# 70                     Cybersecurity       Kirkland  United States
# 72                          Hardware       Shenzhen          China
# 104                           Health       Hangzhou          China
# 133                         Hardware       Shenzhen          China
# ...

# %%
import re

def valuation_to_number(val):
    val = val.replace('$', '')
    if 'B' in val:
        return float(val.replace('B', '')) * 1_000_000_000
    elif 'M' in val:
        return float(val.replace('M', '')) * 1_000_000
    else:
        return float(val)

companies_2015['Valuation_num'] = companies_2015['Valuation'].apply(valuation_to_number)
companies_2015.head(10)
# Out:
#                 Company Valuation Date Joined  \
# 55                Gusto      $10B  2015-12-18
# 70               Tanium       $9B  2015-03-31
# 72      DJI Innovations       $8B  2015-01-23
# 104            WeDoctor       $6B  2015-09-22
# 133  Royole Corporation       $5B  2015-08-18
# 246               Yixia       $3B  2015-11-24
# 299             Illumio       $3B  2015-04-14
# 310           Thumbtack       $3B  2015-09-29
# 374          Tubatu.com       $2B  2015-03-09
# 385           AppDirect       $2B  2015-10-07
#
#                             Industry           City Country/Region  \
# 55                           Fintech  San Francisco  United States
# 70                     Cybersecurity       Kirkland  United States
# 72                          Hardware       Shenzhen          China
# 104                           Health       Hangzhou          China
# 133                         Hardware       Shenzhen          China
# ...

# %%
weekday_order = ['Monday','Tuesday', 'Wednesday', 'Thursday','Friday','Saturday','Sunday']

# %%
companies_2015[['weekday', 'Valuation_num']].groupby(['weekday']).mean()
# Out:
#            Valuation_num
# weekday
# Friday      5.000000e+09
# Monday      1.250000e+09
# Thursday    1.285714e+09
# Tuesday     3.272727e+09
# Wednesday   1.555556e+09

# %%
companies_2015[['weekday', 'Valuation_num']].groupby(['weekday']).median()
# Out:
#            Valuation_num
# weekday
# Friday      4.500000e+09
# Monday      1.000000e+09
# Thursday    1.000000e+09
# Tuesday     3.000000e+09
# Wednesday   2.000000e+09

# %%
month_order = ['January','February', 'March', 'April','May','June','July','August','September','October','November','December']

# %%
month_order
# Out:
# ['January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
companies.dtypes
# Out:
# Company                     object
# Valuation                   object
# Date Joined         datetime64[ns]
# Industry                    object
# City                        object
# Country/Region              object
# Continent                   object
# Year Founded                 int64
# Funding                     object
# Select Investors            object
# Month Joined                object
# weekday                     object
# Year                         int32
# Years_To_Join                int64
# dtype: object

# %%
avg_years_by_founded = companies.groupby('Year Founded')['Years_To_Join'].mean()
avg_years_by_founded
# Out:
# Year Founded
# 1919    98.000000
# 1979    37.000000
# 1984    37.000000
# 1990    27.000000
# 1991    27.000000
# 1992    25.000000
# 1993    28.000000
# 1994    21.500000
# 1995    21.500000
# 1996    25.000000
# 1997    20.000000
# 1998    19.800000
# 1999    19.375000
# 2000    19.272727
# 2001    16.666667
# 2002    13.250000
# 2003    15.500000
# 2004    15.250000
# 2005    13.571429
# 2006    12.933333
# 2007    11.500000
# 2008    11.222222
# 2009    10.147059
# 2010     8.950000
# 2011     8.353659
# 2012     7.463158
# 2013     6.712644
# 2014     6.018349
# 2015     5.200000
# 2016     4.463636
# 2017     3.810811
# 2018     3.114754
# 2019     2.177778
# 2020     1.080000
# 2021     0.000000
# Name: Years_To_Join, dtype: float64

# %%
plt.figure(figsize = (20,5))
plt.bar( x = avg_years_by_founded.index, height= avg_years_by_founded.values)
plt.plot()
plt.xlabel('Year Founded')
plt.ylabel('Avg_Years to Unicon')
plt.title('Average number of years to Unicorn status')
plt.show()

# %%
g = sns.boxplot(data=companies_2015, 
            x='Month Joined',
            y='Valuation_num', 
            order=month_order, 
            showfliers=True)  # False to remove outliers, True to include them

g.set_title('Monthly Valuation (2015)')
g.set_xticklabels(g.get_xticklabels(), rotation=45, fontsize=8)
# Out:
# C:\Users\MBOGO ALFRED\AppData\Local\Temp\ipykernel_26576\372898588.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   g.set_xticklabels(g.get_xticklabels(), rotation=45, fontsize=8)
# [Text(0, 0, 'January'),
#  Text(1, 0, 'February'),
#  Text(2, 0, 'March'),
#  Text(3, 0, 'April'),
#  Text(4, 0, 'May'),
#  Text(5, 0, 'June'),
#  Text(6, 0, 'July'),
#  Text(7, 0, 'August'),
#  Text(8, 0, 'September'),
#  Text(9, 0, 'October'),
#  Text(10, 0, 'November'),
#  Text(11, 0, 'December')]

# %%
companies_2015.head(10)
# Out:
#                 Company Valuation Date Joined  \
# 55                Gusto      $10B  2015-12-18
# 70               Tanium       $9B  2015-03-31
# 72      DJI Innovations       $8B  2015-01-23
# 104            WeDoctor       $6B  2015-09-22
# 133  Royole Corporation       $5B  2015-08-18
# 246               Yixia       $3B  2015-11-24
# 299             Illumio       $3B  2015-04-14
# 310           Thumbtack       $3B  2015-09-29
# 374          Tubatu.com       $2B  2015-03-09
# 385           AppDirect       $2B  2015-10-07
#
#                             Industry           City Country/Region  \
# 55                           Fintech  San Francisco  United States
# 70                     Cybersecurity       Kirkland  United States
# 72                          Hardware       Shenzhen          China
# 104                           Health       Hangzhou          China
# 133                         Hardware       Shenzhen          China
# ...

# %%
companies_2015['Month Joined'].value_counts().plot(kind='bar')
plt.xlabel('Month Joined')
plt.ylabel('Number of Companies')
plt.title('Companies Reaching Unicorn Status by Month (2015)')
plt.show()

# %%
companies_2015['weekday'].value_counts().plot(kind='bar')
plt.xlabel('weekday')
plt.ylabel('Number of Companies')
plt.title('Companies Reaching Unicorn Status by weekday(2015)')
plt.show()
