# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv("D:\Downloads\lightning_strikes.csv")
df
# Out:
#               date  center_point_geom  longitude  latitude  number_of_strikes
# 0       2018-08-01  POINT(-81.6 22.6)      -81.6      22.6                 48
# 1       2018-08-01  POINT(-81.1 22.6)      -81.1      22.6                 32
# 2       2018-08-01  POINT(-80.9 22.6)      -80.9      22.6                118
# 3       2018-08-01  POINT(-80.8 22.6)      -80.8      22.6                 69
# 4       2018-08-01  POINT(-98.4 22.8)      -98.4      22.8                 44
# ...            ...                ...        ...       ...                ...
# 717525  2018-08-31  POINT(-89.6 47.8)      -89.6      47.8                 30
# 717526  2018-08-31  POINT(-89.3 47.5)      -89.3      47.5                 30
# 717527  2018-08-31  POINT(-95.8 47.9)      -95.8      47.9                 30
# 717528  2018-08-31    POINT(-89 47.7)      -89.0      47.7                 30
# 717529  2018-08-31  POINT(-89.4 47.7)      -89.4      47.7                 30
#
# [717530 rows x 5 columns]

# %%
df.head(10)
# Out:
#          date  center_point_geom  longitude  latitude  number_of_strikes
# 0  2018-08-01  POINT(-81.6 22.6)      -81.6      22.6                 48
# 1  2018-08-01  POINT(-81.1 22.6)      -81.1      22.6                 32
# 2  2018-08-01  POINT(-80.9 22.6)      -80.9      22.6                118
# 3  2018-08-01  POINT(-80.8 22.6)      -80.8      22.6                 69
# 4  2018-08-01  POINT(-98.4 22.8)      -98.4      22.8                 44
# 5  2018-08-01    POINT(-81 22.7)      -81.0      22.7                 36
# 6  2018-08-01  POINT(-98.4 22.7)      -98.4      22.7                110
# 7  2018-08-01  POINT(-81.1 22.7)      -81.1      22.7                 48
# 8  2018-08-01  POINT(-80.9 22.7)      -80.9      22.7                 71
# 9  2018-08-01  POINT(-85.7 26.4)      -85.7      26.4                 29

# %%
df.shape
# Out:
# (717530, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 717530 entries, 0 to 717529
# Data columns (total 5 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date               717530 non-null  object
#  1   center_point_geom  717530 non-null  object
#  2   longitude          717530 non-null  float64
#  3   latitude           717530 non-null  float64
#  4   number_of_strikes  717530 non-null  int64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 27.4+ MB

# %%
# Convert date column to datetime
df['date']= pd.to_datetime(df['date'])

# %%
df
# Out:
#              date  center_point_geom  longitude  latitude  number_of_strikes
# 0      2018-08-01  POINT(-81.6 22.6)      -81.6      22.6                 48
# 1      2018-08-01  POINT(-81.1 22.6)      -81.1      22.6                 32
# 2      2018-08-01  POINT(-80.9 22.6)      -80.9      22.6                118
# 3      2018-08-01  POINT(-80.8 22.6)      -80.8      22.6                 69
# 4      2018-08-01  POINT(-98.4 22.8)      -98.4      22.8                 44
# ...           ...                ...        ...       ...                ...
# 717525 2018-08-31  POINT(-89.6 47.8)      -89.6      47.8                 30
# 717526 2018-08-31  POINT(-89.3 47.5)      -89.3      47.5                 30
# 717527 2018-08-31  POINT(-95.8 47.9)      -95.8      47.9                 30
# 717528 2018-08-31    POINT(-89 47.7)      -89.0      47.7                 30
# 717529 2018-08-31  POINT(-89.4 47.7)      -89.4      47.7                 30
#
# [717530 rows x 5 columns]

# %%
# Calculate days with most lightning strikes.
df.groupby(['date']).sum().sort_values('number_of_strikes', ascending=False).head(10)
# Out:
#             number_of_strikes  \
# date
# 2021-11-05               2535
#
#                                             center_point_geom  \
# date
# 2021-11-05  POINT(-80 26)POINT(-83.5 25.8)POINT(-80 25.9)P...
#
#                                                    source_url  \
# date
# 2021-11-05  https://www1.ncdc.noaa.gov/pub/data/swdi/datab...
#
#                                                 etl_timestamp
# date
# 2021-11-05  10/13/2022 2:36:3010/13/2022 2:36:3010/13/2022...

# %%
# Create a new `month` column
df['month'] = df['date'].dt.month
df.head()
# Out:
#         date  center_point_geom  longitude  latitude  number_of_strikes  month
# 0 2018-08-01  POINT(-81.6 22.6)      -81.6      22.6                 48      8
# 1 2018-08-01  POINT(-81.1 22.6)      -81.1      22.6                 32      8
# 2 2018-08-01  POINT(-80.9 22.6)      -80.9      22.6                118      8
# 3 2018-08-01  POINT(-80.8 22.6)      -80.8      22.6                 69      8
# 4 2018-08-01  POINT(-98.4 22.8)      -98.4      22.8                 44      8

# %%
# Calculate total number of strikes per month
df.groupby(['month']).count().sort_values('number_of_strikes', ascending=False)
# Out:
#          date  center_point_geom  longitude  latitude  number_of_strikes
# month
# 8      717530             717530     717530    717530             717530

# %%
# Create a new `month_txt` column.
df['month_txt'] = df['date'].dt.month_name().str.slice(stop=3)
df.head()
# Out:
#         date  number_of_strikes  center_point_geom  \
# 0 2021-11-05                 24      POINT(-80 26)
# 1 2021-11-05                 34  POINT(-83.5 25.8)
# 2 2021-11-05                100    POINT(-80 25.9)
# 3 2021-11-05                 38  POINT(-83.2 25.3)
# 4 2021-11-05                158  POINT(-79.7 26.1)
#
#                                           source_url       etl_timestamp  \
# 0  https://www1.ncdc.noaa.gov/pub/data/swdi/datab...  10/13/2022 2:36:30
# 1  https://www1.ncdc.noaa.gov/pub/data/swdi/datab...  10/13/2022 2:36:30
# 2  https://www1.ncdc.noaa.gov/pub/data/swdi/datab...  10/13/2022 2:36:30
# 3  https://www1.ncdc.noaa.gov/pub/data/swdi/datab...  10/13/2022 2:36:30
# 4  https://www1.ncdc.noaa.gov/pub/data/swdi/datab...  10/13/2022 2:36:30
#
#    month month_txt
# 0     11       Nov
# 1     11       Nov
# 2     11       Nov
# 3     11       Nov
# 4     11       Nov

# %%
# Create a new helper dataframe for plotting.
df_by_month = df.groupby(['month','month_txt']).sum().sort_values('month', ascending=True).head(12).reset_index()
df_by_month

# %%
plt.bar(x=df_by_month['month_txt'],height= df_by_month['number_of_strikes'], label="Number of strikes")
plt.plot()

plt.xlabel("Months(2018)")
plt.ylabel("Number of lightning strikes")
plt.title("Number of lightning strikes in 2018 by months")
plt.legend()
plt.show()
