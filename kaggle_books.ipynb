# %%
# inputting libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

# %%
kaggle = pd.read_excel("E:/R-programming/Kaggle_Books.xlsx")
kaggle
# Out:
#         ID Purchase_Date      Time  Quater  Year  Month  Special_Day  \
# 0        1    2018-01-01  08:57:00       1  2018      1            1
# 1        2    2018-01-02  02:04:00       1  2018      1            1
# 2        3    2018-01-03  05:08:00       1  2018      1            1
# 3        4    2018-01-04  16:06:00       1  2018      1            0
# 4        5    2018-01-04  20:12:00       1  2018      1            0
# ...    ...           ...       ...     ...   ...    ...          ...
# 3475  3476    2019-12-31  12:02:00       4  2019     12            1
# 3476  3477    2019-12-31  02:53:00       4  2019     12            1
# 3477  3478    2019-12-31  06:02:00       4  2019     12            1
# 3478  3479    2019-12-31  07:28:00       4  2019     12            1
# 3479  3480    2019-12-31  09:06:00       4  2019     12            1
#
#       Online_Sale_Offers  Customer_ID Gender  ...       Ship_City  \
# 0                       1   B07FWXWZT      F  ...       Hyderabad
# ...

# %%
kaggle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3480 entries, 0 to 3479
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    3480 non-null   int64
#  1   Purchase_Date         3480 non-null   datetime64[ns]
#  2   Time                  3480 non-null   object
#  3   Quater                3480 non-null   int64
#  4   Year                  3480 non-null   int64
#  5   Month                 3480 non-null   int64
#  6   Special_Day           3480 non-null   int64
#  7   Online_Sale_Offers    3480 non-null   int64
#  8   Customer_ID           3480 non-null   object
#  9   Gender                3480 non-null   object
#  10  Product_Name          3480 non-null   object
#  11  Item_Status           3480 non-null   object
#  12  Quantity              3480 non-null   int64
#  13  Currency              3480 non-null   object
#  14  Item_Price            3480 non-null   float64
# ...

# %%
kaggle.isnull().sum()
# Out:
# ID                      0
# Purchase_Date           0
# Time                    0
# Quater                  0
# Year                    0
# Month                   0
# Special_Day             0
# Online_Sale_Offers      0
# Customer_ID             0
# Gender                  0
# Product_Name            0
# Item_Status             0
# Quantity                0
# Currency                0
# Item_Price              0
# Shipping_Price          0
# Ship_City               0
# Ship_State              0
# Ship_Postal_Code        0
# Category                0
# Total_amount            0
# Author                  0
# Publication             0
# Profit_Percentage(%)    0
# Profit(INR)             0
# Cost_Price              0
# dtype: int64

# %%
kaggle.dtypes
# Out:
# ID                               int64
# Purchase_Date           datetime64[ns]
# Time                            object
# Quater                           int64
# Year                             int64
# Month                            int64
# Special_Day                      int64
# Online_Sale_Offers               int64
# Customer_ID                     object
# Gender                          object
# Product_Name                    object
# Item_Status                     object
# Quantity                         int64
# Currency                        object
# Item_Price                     float64
# Shipping_Price                 float64
# Ship_City                       object
# Ship_State                      object
# Ship_Postal_Code                 int64
# Category                        object
# Total_amount                   float64
# Author                          object
# Publication                     object
# Profit_Percentage(%)             int64
# ...

# %%
#quantity by purchase date
top_date= kaggle.groupby('Purchase_Date')['Quantity'].sum().sort_values(ascending = False).head(10)
top_date
# Out:
# Purchase_Date
# 2019-04-07    55
# 2019-06-01    47
# 2019-04-03    47
# 2019-04-04    35
# 2019-07-27    35
# 2019-05-16    33
# 2019-08-09    32
# 2019-05-15    31
# 2019-07-10    29
# 2019-07-24    25
# Name: Quantity, dtype: int64

# %%
top_date.plot(kind = 'line', title = 'TOP DATES BY QUANTITY OF BOOKS PURCHASED', ylabel = 'quantity purchased')
# Out:
# <Axes: title={'center': 'TOP DATES BY QUANTITY OF BOOKS PURCHASED'}, xlabel='Purchase_Date', ylabel='quantity purchased'>

# %%
#quantity by quater
top_quater= kaggle.groupby('Quater')['Quantity'].sum().sort_values(ascending = False)
top_quater
# Out:
# Quater
# 2    1574
# 3    1080
# 1     589
# 4     412
# Name: Quantity, dtype: int64

# %%
top_quater.plot(kind = 'bar', title = 'QUATERS BY QUANTITY OF BOOKS PURCHASED',ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUATERS BY QUANTITY OF BOOKS PURCHASED'}, xlabel='Quater', ylabel='total books purchased'>

# %%
#quantity by year
top_year = kaggle.groupby('Year')['Quantity'].sum().sort_values(ascending = False)
top_year
# Out:
# Year
# 2019    2408
# 2018    1247
# Name: Quantity, dtype: int64

# %%
top_year.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY YEAR',ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY YEAR'}, xlabel='Year', ylabel='total books purchased'>

# %%
#quantity by month
top_month= kaggle.groupby('Month')['Quantity'].sum().sort_values(ascending = False)
top_month
# Out:
# Month
# 4     608
# 5     561
# 7     545
# 6     405
# 8     304
# 3     257
# 9     231
# 1     170
# 2     162
# 11    148
# 12    133
# 10    131
# Name: Quantity, dtype: int64

# %%
top_month.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY MONTH', ylabel ='total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY MONTH'}, xlabel='Month', ylabel='total books purchased'>

# %%
#quantity by gender
top_gender= kaggle.groupby('Gender')['Quantity'].sum().sort_values(ascending = False)
top_gender
# Out:
# Gender
# M    1908
# F    1747
# Name: Quantity, dtype: int64

# %%
top_gender.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY GENDER', ylabel ='total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY GENDER'}, xlabel='Gender', ylabel='total books purchased'>

# %%
#quantity by product(book) name
top_product= kaggle.groupby('Product_Name')['Quantity'].sum().sort_values(ascending = False).head(10)
top_product
# Out:
# Product_Name
# Lakshya Rajasthan Ki Kala, Sanskriti Va Itihas 2019 Bhag-2                  246
# Science Textbook for Class - 6  - 652                                       209
# Science textbook for Class -7 - 2020 (NCERT)                                166
# Bal RamKatha - TextBook in Hindi for Class - 6  - 645                       157
# Chemistry Textbook Part - 2 for Class - 12 with Free Car Anti Slip Mat      152
# Mathematics Textbook for Class - 6  - 650                                   131
# Words And Expressions 1 For Class 9- 976                                     92
# English 9th class workbook Words & Expression Ncert                          79
# Ruchira Bhag - 1 Sanskrit Textbook for Class - 6  - 649                      78
# Accountancy Financial Accounting Part - 1 Textbook for Class - 11- 11110     77
# Name: Quantity, dtype: int64

# %%
top_product.plot(kind = 'bar', title = 'QUANTITY OF TOP 10 BOOKS PURCHASED BY PRODUCT NAME', ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF TOP 10 BOOKS PURCHASED BY PRODUCT NAME'}, xlabel='Product_Name', ylabel='total books purchased'>

# %%
#quantity by product
top_product= kaggle.groupby('Product_Name')['Quantity'].sum().sort_values(ascending = True).head(20)
top_product
# Out:
# Product_Name
# Guide to RRB Electrical Engg. (Senior Section Engineer) 2016                                                                                     1
# Data Structures and Algorithms Made Easy : Second Edition: Data Structure and Algorithmic Puzzles                                                1
# Trueman's Elementary Biology for class 11 and NEET - Vol. I (2020 Edition)                                                                       1
# Kritika Bhag - 2 TextBook in Hindi for Class 10  - 1056                                                                                          1
# Collins Easy Learner's Dictionary                                                                                                                1
# Lakshay PTET Pre B.ED                                                                                                                            1
# ...

# %%
#quantity by ship city
top_city= kaggle.groupby('Ship_City')['Quantity'].sum().sort_values(ascending = False).head(10)
top_city
# Out:
# Ship_City
# NEW DELHI    218
# BENGALURU    191
# MUMBAI       131
# PUNE         105
# JAIPUR        85
# AHMEDABAD     74
# CHENNAI       68
# HYDERABAD     68
# GURUGRAM      63
# LUCKNOW       57
# Name: Quantity, dtype: int64

# %%
top_city.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY SHIP CITY', ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY SHIP CITY'}, xlabel='Ship_City', ylabel='total books purchased'>

# %%
#quantity by ship state
top_state= kaggle.groupby('Ship_State')['Quantity'].sum().sort_values(ascending = False).head(10)
top_state
# Out:
# Ship_State
# MAHARASHTRA      600
# UTTAR PRADESH    352
# RAJASTHAN        311
# KARNATAKA        307
# GUJARAT          270
# DELHI            259
# TAMIL NADU       216
# HARYANA          202
# WEST BENGAL      146
# TELANGANA        105
# Name: Quantity, dtype: int64

# %%
top_state.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY SHIP STATE', ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY SHIP STATE'}, xlabel='Ship_State', ylabel='total books purchased'>

# %%
#quantity by category
top_category= kaggle.groupby('Category')['Quantity'].sum().sort_values(ascending = False)
top_category
# Out:
# Category
# school          1350
# competition      872
# college          793
# School           640
# Name: Quantity, dtype: int64

# %%
top_category.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY CATEGORY', ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY CATEGORY'}, xlabel='Category', ylabel='total books purchased'>

# %%
#quantity by Author
top_author= kaggle.groupby('Author')['Quantity'].sum().sort_values(ascending = False).head(10)
top_author
# Out:
# Author
# NCERT                                       1708
# MAHAVEER JAIN,ANSHUL JAIN KANTI JAIN         246
# preeti agarwal, r.s. sharma, vinod gupta      79
# Multiple Authors                              79
# Preeti Agarwal                                76
# Kanti Jain                                    72
# N. Gregory Mankiw                             66
# Andrew S. Tanenbaum                           60
# Â Kanti Jain                                  58
# R.S Aggarwal                                  49
# Name: Quantity, dtype: int64

# %%
top_author.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY AUTHOR', ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY AUTHOR'}, xlabel='Author', ylabel='total books purchased'>

# %%
#quantity by publication
top_publication= kaggle.groupby('Publication')['Quantity'].sum().sort_values(ascending = False).head(10)
top_publication
# Out:
# Publication
# National Council of Education Research and Training           1421
# VK Global Publications Private Limited                         255
# National Council of Education Research and Training (2014)     237
# Manu Prakashan Private Limited                                 128
# Arihant Publications                                            87
# Multiple Authors Publishing                                     79
# Vardhan                                                         79
# Vardhan Publishers & Distributors                               76
# Aravali Publication                                             66
# OpenStax                                                        66
# Name: Quantity, dtype: int64

# %%
top_publication.plot(kind = 'bar', title = 'QUANTITY OF BOOKS PURCHASED BY PUBLICATION', ylabel = 'total books purchased')
# Out:
# <Axes: title={'center': 'QUANTITY OF BOOKS PURCHASED BY PUBLICATION'}, xlabel='Publication', ylabel='total books purchased'>

# %%
#total quantity purchased by customer
top_customer = kaggle.groupby('Customer_ID')['Quantity'].sum().sort_values(ascending = False).head(10)
top_customer
# Out:
# Customer_ID
# B07FWWBYQ    10
# B07FWYUYQ     9
# B07FWVUVY     9
# B07FWVUSV     8
# B07FWVUUU     8
# B07FWVVWQ     8
# B07FWVWQY     7
# B07FWVVZT     7
# B07FWVYVQ     7
# B07FWVUVZ     7
# Name: Quantity, dtype: int64

# %%
top_customer.plot(kind = 'bar', title = 'TOP CUSTOMERS BY QUANTITY PURCHASED', ylabel = 'total quantity purchased')
# Out:
# <Axes: title={'center': 'TOP CUSTOMERS BY QUANTITY PURCHASED'}, xlabel='Customer_ID', ylabel='total quantity purchased'>

# %%
#total amount by purchase date
top_date1= kaggle.groupby('Purchase_Date')['Total_amount'].sum().sort_values(ascending = False).head(10)
top_date1
# Out:
# Purchase_Date
# 2019-07-28    12462.00
# 2018-04-09    12093.00
# 2019-06-01    12036.00
# 2019-07-27    11225.80
# 2018-01-15    11118.00
# 2019-06-07    10681.45
# 2018-05-13    10585.00
# 2018-03-07    10264.00
# 2019-04-07    10150.24
# 2018-04-07     9765.00
# Name: Total_amount, dtype: float64

# %%
top_date1.plot(kind = 'line', title = 'TOP DATES BY TOTAL AMOUNT SPENT ON BOOKS PURCHASED', ylabel = 'total amount spent')
# Out:
# <Axes: title={'center': 'TOP DATES BY TOTAL AMOUNT SPENT ON BOOKS PURCHASED'}, xlabel='Purchase_Date', ylabel='total amount spent'>

# %%
#total amount by year
top_year1 = kaggle.groupby('Year')['Total_amount'].sum().sort_values(ascending = False)
top_year1
# Out:
# Year
# 2019    839793.79
# 2018    749789.72
# Name: Total_amount, dtype: float64

# %%
top_year1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY YEAR',ylabel = 'total spent on books purchased')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY YEAR'}, xlabel='Year', ylabel='total spent on books purchased'>

# %%
#Total amount by quater
top_quater1= kaggle.groupby('Quater')['Total_amount'].sum().sort_values(ascending = False)
top_quater1
# Out:
# Quater
# 2    564338.23
# 3    419632.43
# 1    388978.95
# 4    216633.90
# Name: Total_amount, dtype: float64

# %%
top_quater1.plot(kind = 'bar', title = 'QUATERS BY TOTAL AMOUNT SPENT ON BOOKS PURCHASED',ylabel = 'total amount spent on books purchased')
# Out:
# <Axes: title={'center': 'QUATERS BY TOTAL AMOUNT SPENT ON BOOKS PURCHASED'}, xlabel='Quater', ylabel='total amount spent on books purchased'>

# %%
#Total_amount spent on books by month
top_month1= kaggle.groupby('Month')['Total_amount'].sum().sort_values(ascending = False)
top_month1
# Out:
# Month
# 4     215493.08
# 5     201417.35
# 7     178028.37
# 3     170001.95
# 6     147427.80
# 8     141504.91
# 1     114498.00
# 2     104479.00
# 9     100099.15
# 12     73566.50
# 11     72277.00
# 10     70790.40
# Name: Total_amount, dtype: float64

# %%
top_month1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY MONTH', ylabel ='total amount spent on books purchased')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY MONTH'}, xlabel='Month', ylabel='total amount spent on books purchased'>

# %%
#Total_amount spent by gender
top_gender1= kaggle.groupby('Gender')['Total_amount'].sum().sort_values(ascending = False)
top_gender1
# Out:
# Gender
# M    835050.24
# F    754533.27
# Name: Total_amount, dtype: float64

# %%
top_gender1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY GENDER', ylabel ='total amount spent on books purchased')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY GENDER'}, xlabel='Gender', ylabel='total amount spent on books purchased'>

# %%
#total_amount spent by product(book) name
top_product1= kaggle.groupby('Product_Name')['Total_amount'].sum().sort_values(ascending = False).head(10)
top_product1
# Out:
# Product_Name
# Lakshya Rajasthan Ki Kala, Sanskriti Va Itihas 2019 Bhag-2                                     113102.61
# Vardhan Comprehensive Guide for NURSING Competitive Examinations (3rd Revised edition 2018)     58307.00
# COMPREHENSIVE GUIDE FOR NURSING COMPETITIVE EXAM                                                50210.00
# Principles of Microeconomics                                                                    47661.00
# Mathematics Textbook for Class - 6  - 650                                                       46933.97
# Objective Biology NEET & AIIMS (Set of 2 Volumes) (2020-2020)Session by Dr. Ali                 46215.00
# English Grammar for Today: A New Introduction                                                   45823.00
# Science textbook for Class -7 - 2020 (NCERT)                                                    41641.18
# Chemistry Textbook Part - 2 for Class - 12 with Free Car Anti Slip Mat                          39658.00
# ...

# %%
top_product1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY BOOK NAME', ylabel ='total amount spent on books purchased')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY BOOK NAME'}, xlabel='Product_Name', ylabel='total amount spent on books purchased'>

# %%
#Total amount spent by ship city
top_city1= kaggle.groupby('Ship_City')['Total_amount'].sum().sort_values(ascending = False).head(10)
top_city1
# Out:
# Ship_City
# NEW DELHI    100767.31
# BENGALURU     69214.91
# MUMBAI        58909.92
# PUNE          47722.79
# JAIPUR        45788.79
# AHMEDABAD     34511.35
# CHENNAI       25960.67
# GURUGRAM      25624.18
# HYDERABAD     24237.74
# LUCKNOW       19435.24
# Name: Total_amount, dtype: float64

# %%
top_city1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY CITY', ylabel ='total amount spent on books purchased')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY CITY'}, xlabel='Ship_City', ylabel='total amount spent on books purchased'>

# %%
#quantity by ship state
top_state1= kaggle.groupby('Ship_State')['Total_amount'].sum().sort_values(ascending = False).head(10)
top_state1
# Out:
# Ship_State
# MAHARASHTRA      278712.30
# RAJASTHAN        158869.23
# UTTAR PRADESH    144164.28
# DELHI            116767.26
# GUJARAT          110448.59
# KARNATAKA        105289.17
# TAMIL NADU        87567.96
# HARYANA           83314.12
# WEST BENGAL       62171.01
# TELANGANA         39947.65
# Name: Total_amount, dtype: float64

# %%
top_state1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY STATE', ylabel ='total amount spent on books purchased')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY STATE'}, xlabel='Ship_State', ylabel='total amount spent on books purchased'>

# %%
#total amount by category
top_category1= kaggle.groupby('Category')['Total_amount'].sum().sort_values(ascending = False)
top_category1
# Out:
# Category
# college         548991.50
# competition     503906.39
# school          330134.64
# School          206550.98
# Name: Total_amount, dtype: float64

# %%
top_category1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY CATEGORY', ylabel = 'total amount spent')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY CATEGORY'}, xlabel='Category', ylabel='total amount spent'>

# %%
#total amount by Author
top_author1= kaggle.groupby('Author')['Total_amount'].sum().sort_values(ascending = False).head(10)
top_author1
# Out:
# Author
# NCERT                                       407290.39
# MAHAVEER JAIN,ANSHUL JAIN KANTI JAIN        113102.61
# preeti agarwal, r.s. sharma, vinod gupta     73107.00
# Preeti Agarwal                               50210.00
# N. Gregory Mankiw                            47661.00
# Geoffrey Leech                               46401.00
# DR.Â ALI AKHTER                              46215.00
# Â M.D. Raisinghania                          37681.00
# Dr.H.L.AHUJA                                 32790.00
# Ahuja H.L.                                   29229.00
# Name: Total_amount, dtype: float64

# %%
top_author1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY AUTHOR', ylabel = 'total amount spent')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY AUTHOR'}, xlabel='Author', ylabel='total amount spent'>

# %%
#total amount by publication
top_publication1 = kaggle.groupby('Publication')['Total_amount'].sum().sort_values(ascending = False).head(10)
top_publication1
# Out:
# Publication
# National Council of Education Research and Training           339217.64
# VK Global Publications Private Limited                        116657.61
# Vardhan                                                        73107.00
# National Council of Education Research and Training (2014)     60728.37
# S. Chand Publishing                                            55948.00
# Manu Prakashan Private Limited                                 52426.78
# Arihant Publications                                           51510.00
# Vardhan Publishers & Distributors                              50210.00
# OpenStax                                                       47661.00
# SASA PUBLICATION                                               46215.00
# Name: Total_amount, dtype: float64

# %%
top_publication1.plot(kind = 'bar', title = 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY PUBLICATION', ylabel = 'total amount spent')
# Out:
# <Axes: title={'center': 'TOTAL AMOUNT SPENT ON BOOKS PURCHASED BY PUBLICATION'}, xlabel='Publication', ylabel='total amount spent'>

# %%
#total amount purchased by customer
top_customer1 = kaggle.groupby('Customer_ID')['Total_amount'].sum().sort_values(ascending = False).head(10)
top_customer1
# Out:
# Customer_ID
# B07FWWBYQ    7300.0
# B07FWXZXT    5912.0
# B07FWVUUU    5854.5
# B07FWVUVY    5440.5
# B07FWVVWQ    4578.0
# B07FWVVRW    4332.0
# B07FWVVYX    4057.5
# B07FWVUSW    3914.0
# B07FWVWWW    3815.0
# B07FWXUTS    3808.0
# Name: Total_amount, dtype: float64

# %%
top_customer1.plot(kind = 'bar', title = 'TOP CUSTOMERS BY TOTAL AMOUNT SPENT', ylabel = 'total amount spent')
# Out:
# <Axes: title={'center': 'TOP CUSTOMERS BY TOTAL AMOUNT SPENT'}, xlabel='Customer_ID', ylabel='total amount spent'>

# %%
#profit made by purchase date
top_date2 = kaggle.groupby('Purchase_Date')['Profit(INR)'].sum().sort_values(ascending = False).head(10)
top_date2
# Out:
# Purchase_Date
# 2019-07-28    1796.230
# 2019-06-01    1718.380
# 2019-07-27    1643.224
# 2018-04-09    1597.690
# 2019-06-07    1569.521
# 2018-05-13    1545.300
# 2018-01-15    1400.850
# 2018-03-29    1329.940
# 2018-05-02    1276.880
# 2018-02-25    1272.960
# Name: Profit(INR), dtype: float64

# %%
top_date2.plot(kind = 'line', title = 'HIGHLY PROFITABLE PURCHASE_DATES', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'HIGHLY PROFITABLE PURCHASE_DATES'}, xlabel='Purchase_Date', ylabel='Profit(INR)'>

# %%
#profit made by year
top_year2 = kaggle.groupby('Year')['Profit(INR)'].sum().sort_values(ascending = False)
top_year2
# Out:
# Year
# 2019    108358.4272
# 2018     99780.7500
# Name: Profit(INR), dtype: float64

# %%
top_year2.plot(kind = 'bar', title = 'PROFIT MADE BY YEARS', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'PROFIT MADE BY YEARS'}, xlabel='Year', ylabel='Profit(INR)'>

# %%
#profit made by quaters
top_quater2= kaggle.groupby('Quater')['Profit(INR)'].sum().sort_values(ascending = False)
top_quater2
# Out:
# Quater
# 2    74210.4514
# 3    55674.6278
# 1    50339.2160
# 4    27914.8820
# Name: Profit(INR), dtype: float64

# %%
top_quater2.plot(kind = 'bar', title = 'PROFIT MADE BY QUATER', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'PROFIT MADE BY QUATER'}, xlabel='Quater', ylabel='Profit(INR)'>

# %%
#profit made on books by month
top_month2= kaggle.groupby('Month')['Profit(INR)'].sum().sort_values(ascending = False)
top_month2
# Out:
# Month
# 5     27930.9130
# 4     25460.2544
# 7     24393.0564
# 3     20976.3460
# 6     20819.2840
# 8     18861.5544
# 1     15132.6200
# 2     14230.2500
# 9     12420.0170
# 12     9857.4650
# 11     9177.2400
# 10     8880.1770
# Name: Profit(INR), dtype: float64

# %%
top_month2.plot(kind = 'bar', title = 'PROFIT MADE BY MONTH', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'PROFIT MADE BY MONTH'}, xlabel='Month', ylabel='Profit(INR)'>

# %%
#profit made by gender
top_gender2= kaggle.groupby('Gender')['Profit(INR)'].sum().sort_values(ascending = False)
top_gender2
# Out:
# Gender
# M    109645.3394
# F     98493.8378
# Name: Profit(INR), dtype: float64

# %%
top_gender2.plot(kind = 'bar', title = 'PROFIT MADE BY GENDER', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'PROFIT MADE BY GENDER'}, xlabel='Gender', ylabel='Profit(INR)'>

# %%
#total profit made by product(book) name
top_product2= kaggle.groupby('Product_Name')['Profit(INR)'].sum().sort_values(ascending = False).head(10)
top_product2
# Out:
# Product_Name
# Lakshya Rajasthan Ki Kala, Sanskriti Va Itihas 2019 Bhag-2                                     16518.90
# English Grammar for Today: A New Introduction                                                   7595.28
# COMPREHENSIVE GUIDE FOR NURSING COMPETITIVE EXAM                                                7441.92
# Objective Biology NEET & AIIMS (Set of 2 Volumes) (2020-2020)Session by Dr. Ali                 7125.72
# Vardhan Comprehensive Guide for NURSING Competitive Examinations (3rd Revised edition 2018)     6879.60
# Mathematics Textbook for Class - 6  - 650                                                       6720.30
# Principles of Microeconomics                                                                    5478.33
# Chemistry Textbook Part - 2 for Class - 12 with Free Car Anti Slip Mat                          5253.12
# Science textbook for Class -7 - 2020 (NCERT)                                                    5229.00
# ...

# %%
top_product2.plot(kind = 'bar', title = 'TOTAL PROFIT MADE BY BOOK', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'TOTAL PROFIT MADE BY BOOK'}, xlabel='Product_Name', ylabel='Profit(INR)'>

# %%
#Total profit made by ship city
top_city2= kaggle.groupby('Ship_City')['Profit(INR)'].sum().sort_values(ascending = False).head(10)
top_city2
# Out:
# Ship_City
# NEW DELHI    13412.3108
# BENGALURU     9154.0462
# MUMBAI        8010.1048
# PUNE          6379.7522
# JAIPUR        6139.6410
# AHMEDABAD     4591.1978
# CHENNAI       3384.9018
# GURUGRAM      3294.1374
# HYDERABAD     3204.1424
# LUCKNOW       2560.1032
# Name: Profit(INR), dtype: float64

# %%
top_city2.plot(kind = 'bar', title = 'TOTAL PROFIT MADE BY EACH CITY', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'TOTAL PROFIT MADE BY EACH CITY'}, xlabel='Ship_City', ylabel='Profit(INR)'>

# %%
#quantity by ship state
top_state2= kaggle.groupby('Ship_State')['Profit(INR)'].sum().sort_values(ascending = False).head(10)
top_state2
# Out:
# Ship_State
# MAHARASHTRA      37107.7466
# RAJASTHAN        21266.4178
# UTTAR PRADESH    18501.0892
# DELHI            15605.3368
# GUJARAT          14835.4036
# KARNATAKA        13992.6486
# TAMIL NADU       11599.7396
# HARYANA          10641.8128
# WEST BENGAL       8054.9518
# TELANGANA         5208.7562
# Name: Profit(INR), dtype: float64

# %%
top_state2.plot(kind = 'bar', title = 'TOTAL PROFIT MADE BY EACH STATE', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'TOTAL PROFIT MADE BY EACH STATE'}, xlabel='Ship_State', ylabel='Profit(INR)'>

# %%
#total profit by category
top_category2= kaggle.groupby('Category')['Profit(INR)'].sum().sort_values(ascending = False)
top_category2
# Out:
# Category
# competition     74385.5400
# college         62676.4450
# school          41701.5522
# School          29375.6400
# Name: Profit(INR), dtype: float64

# %%
top_category2.plot(kind = 'bar', title = 'TOTAL PROFIT MADE BY CATEGORY', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'TOTAL PROFIT MADE BY CATEGORY'}, xlabel='Category', ylabel='Profit(INR)'>

# %%
#total profit by Author
top_author2= kaggle.groupby('Author')['Profit(INR)'].sum().sort_values(ascending = False).head(10)
top_author2
# Out:
# Author
# NCERT                                       51693.7032
# MAHAVEER JAIN,ANSHUL JAIN KANTI JAIN        16518.9000
# preeti agarwal, r.s. sharma, vinod gupta     8626.8000
# Geoffrey Leech                               7675.9200
# Preeti Agarwal                               7441.9200
# DR.Â ALI AKHTER                              7125.7200
# N. Gregory Mankiw                            5478.3300
# A. Biswas, S. Biswas                         4467.6000
# Â M.D. Raisinghania                          4324.1900
# Kanti Jain                                   3916.8000
# Name: Profit(INR), dtype: float64

# %%
top_author2.plot(kind = 'bar', title = 'TOTAL PROFIT MADE BY AUTHOR', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'TOTAL PROFIT MADE BY AUTHOR'}, xlabel='Author', ylabel='Profit(INR)'>

# %%
#total profit by publication
top_publication2 = kaggle.groupby('Publication')['Profit(INR)'].sum().sort_values(ascending = False).head(10)
top_publication2
# Out:
# Publication
# National Council of Education Research and Training           42842.7432
# VK Global Publications Private Limited                        17021.1000
# Vardhan                                                        8626.8000
# National Council of Education Research and Training (2014)     8028.9000
# Palgrave Macmillan                                             7595.2800
# Vardhan Publishers & Distributors                              7441.9200
# Manu Prakashan Private Limited                                 7425.6000
# Arihant Publications                                           7328.3900
# SASA PUBLICATION                                               7125.7200
# S. Chand Publishing                                            6428.7300
# Name: Profit(INR), dtype: float64

# %%
top_publication2.plot(kind = 'bar', title = 'TOTAL PROFIT MADE BY PUBLICATION', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'TOTAL PROFIT MADE BY PUBLICATION'}, xlabel='Publication', ylabel='Profit(INR)'>

# %%
#total profit by customer
top_customer2 = kaggle.groupby('Customer_ID')['Profit(INR)'].sum().sort_values(ascending = False).head(10)
top_customer2
# Out:
# Customer_ID
# B07FWXZXT    1035.720
# B07FWWBYQ     838.500
# B07FWVUUU     722.105
# B07FWVUVY     708.765
# B07FWVVWQ     698.010
# B07FWVVUV     551.391
# B07FWVVRW     534.720
# B07FWVUSV     532.080
# B07FWVUSW     513.390
# B07FWWXXS     508.980
# Name: Profit(INR), dtype: float64

# %%
top_customer2.plot(kind = 'bar', title = 'TOTAL PROFIT MADE BY CUSTOMER', ylabel = 'Profit(INR)')
# Out:
# <Axes: title={'center': 'TOTAL PROFIT MADE BY CUSTOMER'}, xlabel='Customer_ID', ylabel='Profit(INR)'>

# %%
plt.figure(figsize=(12,10))
axis = sns.scatterplot(x="Item_Price", y="Shipping_Price", data= kaggle, hue ='Category' )
plt.title('ITEM PRICE VS SHIPPING PRICE')
# Out:
# Text(0.5, 1.0, 'ITEM PRICE VS SHIPPING PRICE')

# %%
plt.figure(figsize=(12,10))
axis = sns.scatterplot(x="Item_Price", y="Total_amount", data= kaggle, hue ='Category' )
plt.title('ITEM PRICE VS TOTAL AMOUNT')
# Out:
# Text(0.5, 1.0, 'ITEM PRICE VS TOTAL AMOUNT')

# %%
plt.figure(figsize=(12,10))
axis = sns.scatterplot(x="Item_Price", y="Profit(INR)", data= kaggle, hue ='Category' )
plt.title('ITEM PRICE VS PROFIT(INR)')
# Out:
# Text(0.5, 1.0, 'ITEM PRICE VS PROFIT(INR)')

# %%
#Total_amount spent by gender
top_gender3 = kaggle.groupby('Gender')['Gender'].count().sort_values(ascending = False)
top_gender3
# Out:
# Gender
# M    1815
# F    1665
# Name: Gender, dtype: int64

# %%
top_gender3.plot.pie(autopct = '%1.1f%%')
plt.title("GENDER DISTRIBUTION")
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
