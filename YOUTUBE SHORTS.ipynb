# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

# %%
#importing datasets
youtube = pd.read_csv("E:/PYTHON/most_viewed_youtube_shorts.csv")
youtube
# Out:
#                                                  title  view_count  \
# 0     She Was "One Minute" Away From Disaster! #shorts   746717484
# 1                                I HAVE BANGS… #Shorts   555825641
# 2      funny vadieo subscribe for more vadieos #shorts   482962560
# 3       She turned pregnant and he let her go! #shorts   415148935
# 4                  Tom&Jerry.. Real End Twist 😆#shorts   395791994
# ..                                                 ...         ...
# 595  Sweet love story ❤️ #love #shorts #couplegoals...      339585
# 596                  Test an Verlobten😂 #funny #shorts      294921
# 597  TESTE PARA SABER SE VOCÊ É ALIENÍGENA… 😰🛸👽 #sh...      297353
# 598                   Biasanya kebalikan malah🗿#shorts      289290
# 599  Tried Trending *KOREAN PANCAKE*🔥Korean Vegetab...      287413
#
#      like_count  comment_count  published_      time  duration_s
# 0    13068287.0        19863.0   2/11/2023  16:39:01          59
# ...

# %%
#detailing the youtube dataset
youtube.describe(include ='all')
# Out:
#                                                     title    view_count  \
# count                                                 600  6.000000e+02
# unique                                                567           NaN
# top     Tom 🍓 Jerry (Rithvi&Kavi)Real End Twist 😂🎈 #sh...           NaN
# freq                                                    3           NaN
# mean                                                  NaN  4.754194e+07
# std                                                   NaN  7.571700e+07
# min                                                   NaN  2.874130e+05
# 25%                                                   NaN  7.855342e+06
# 50%                                                   NaN  2.165652e+07
# 75%                                                   NaN  4.776332e+07
# max                                                   NaN  7.467175e+08
#
#           like_count  comment_count published_      time  duration_s
# ...

# %%
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          600 non-null    object
#  1   view_count     600 non-null    int64
#  2   like_count     572 non-null    float64
#  3   comment_count  572 non-null    float64
#  4   published_     600 non-null    object
#  5   time           600 non-null    object
#  6   duration_s     600 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 32.9+ KB

# %%
youtube.isnull().sum()
# Out:
# title             0
# view_count        0
# like_count       28
# comment_count    28
# published_        0
# time              0
# duration_s        0
# dtype: int64

# %%
youtube.dtypes
# Out:
# title             object
# view_count         int64
# like_count       float64
# comment_count    float64
# published_        object
# time              object
# duration_s         int64
# dtype: object

# %%
#replacing null, nan and na
youtube = youtube.fillna(' ')
youtube
# Out:
#                                                  title  view_count  \
# 0     She Was "One Minute" Away From Disaster! #shorts   746717484
# 1                                I HAVE BANGS… #Shorts   555825641
# 2      funny vadieo subscribe for more vadieos #shorts   482962560
# 3       She turned pregnant and he let her go! #shorts   415148935
# 4                  Tom&Jerry.. Real End Twist 😆#shorts   395791994
# ..                                                 ...         ...
# 595  Sweet love story ❤️ #love #shorts #couplegoals...      339585
# 596                  Test an Verlobten😂 #funny #shorts      294921
# 597  TESTE PARA SABER SE VOCÊ É ALIENÍGENA… 😰🛸👽 #sh...      297353
# 598                   Biasanya kebalikan malah🗿#shorts      289290
# 599  Tried Trending *KOREAN PANCAKE*🔥Korean Vegetab...      287413
#
#      like_count comment_count  published_      time  duration_s
# 0    13068287.0       19863.0   2/11/2023  16:39:01          59
# ...

# %%
youtube.isnull().sum()
# Out:
# title            0
# view_count       0
# like_count       0
# comment_count    0
# published_       0
# time             0
# duration_s       0
# dtype: int64

# %%
youtube.plot(kind = 'line', subplots = True, title = 'youtube shorts')
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
youtube.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'view_count'}>,
#         <Axes: title={'center': 'duration_s'}>]], dtype=object)

# %%
sns.pairplot(youtube)
# Out:
# C:\Users\MBOGO ANGEL ALFRED\ANACONDA\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# finding the outliers
sns.boxplot(x=youtube["duration_s"])
# Out:
# <Axes: xlabel='duration_s'>

# %%
# finding the outliers
sns.boxplot(x=youtube["view_count"])
# Out:
# <Axes: xlabel='view_count'>

# %%
#titles by view_count
top_view = youtube.groupby('title')['view_count'].sum().sort_values(ascending = False).head(10)
top_view
# Out:
# title
# She Was "One Minute" Away From Disaster! #shorts                                                       746717484
# I HAVE BANGS… #Shorts                                                                                  555825641
# funny vadieo subscribe for more vadieos #shorts                                                        482962560
# New Gadgets, Smart Appliances, Kitchen Tools, Utensils, Home Cleaning/Beauty, Accessories 😍 #shorts    477220384
# She turned pregnant and he let her go! #shorts                                                         415148935
# Tom&Jerry.. Real End Twist 😆#shorts                                                                    395791994
# Gadgets, Smart Appliances, Kitchen Utensils/Home Cleaning/Inventions P200  #shorts                     368805339
# कामवाली बाई और विराट कोहली 🏏😂 IPL | Kaamwali Bai Part 16 #Shorts #Shortsbreak                          350916014
# ...

# %%
top_view.plot(kind = 'bar', title = 'COMPARISON OF VIEWS BY TITLE', ylabel = 'number of views')
# Out:
# <Axes: title={'center': 'COMPARISON OF VIEWS BY TITLE'}, xlabel='title', ylabel='number of views'>
# C:\Users\MBOGO ANGEL ALFRED\ANACONDA\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 128525 (\N{SMILING FACE WITH HEART-SHAPED EYES}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\MBOGO ANGEL ALFRED\ANACONDA\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 128518 (\N{SMILING FACE WITH OPEN MOUTH AND TIGHTLY-CLOSED EYES}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\MBOGO ANGEL ALFRED\ANACONDA\Lib\site-packages\IPython\core\events.py:93: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\MBOGO ANGEL ALFRED\ANACONDA\Lib\site-packages\IPython\core\events.py:93: UserWarning: Matplotlib currently does not support Devanagari natively.
#   func(*args, **kwargs)
# ...

# %%
youtube.dtypes
# Out:
# title            object
# view_count        int64
# like_count       object
# comment_count    object
# published_       object
# time             object
# duration_s        int64
# dtype: object
