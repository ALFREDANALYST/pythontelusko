# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
#importing datasets
air_bnb     = pd.read_csv("E:/PYTHON/Airbnb_Data.csv")

# %%
air_bnb
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
#analysis of airbnb dataset
air_bnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
# ...

# %%
air_bnb.dtypes
# Out:
# id                          int64
# log_price                 float64
# property_type              object
# room_type                  object
# amenities                  object
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# cancellation_policy        object
# cleaning_fee                 bool
# city                       object
# description                object
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate         object
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# name                       object
# neighbourhood              object
# number_of_reviews           int64
# review_scores_rating      float64
# thumbnail_url              object
# zipcode                    object
# ...

# %%
air_bnb.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
air_bnb.isnull().sum()
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   200
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              15864
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# instant_bookable              0
# last_review               15827
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              6872
# number_of_reviews             0
# review_scores_rating      16722
# thumbnail_url              8216
# zipcode                     966
# bedrooms                     91
# beds                        131
# ...

# %%
air_bnb.drop_duplicates()
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
air_bnb.describe(include = 'all')
# Out:
#                   id     log_price property_type        room_type amenities  \
# count   7.411100e+04  74111.000000         74111            74111     74111
# unique           NaN           NaN            35                3     67122
# top              NaN           NaN     Apartment  Entire home/apt        {}
# freq             NaN           NaN         49003            41310       586
# mean    1.126662e+07      4.782069           NaN              NaN       NaN
# std     6.081735e+06      0.717394           NaN              NaN       NaN
# min     3.440000e+02      0.000000           NaN              NaN       NaN
# 25%     6.261964e+06      4.317488           NaN              NaN       NaN
# 50%     1.225415e+07      4.709530           NaN              NaN       NaN
# 75%     1.640226e+07      5.220356           NaN              NaN       NaN
# max     2.123090e+07      7.600402           NaN              NaN       NaN
#
# ...

# %%
air_bnb['review_scores_rating']
# Out:
# 0        100.0
# 1         93.0
# 2         92.0
# 3          NaN
# 4         40.0
#          ...
# 74106      NaN
# 74107     93.0
# 74108     94.0
# 74109      NaN
# 74110     96.0
# Name: review_scores_rating, Length: 74111, dtype: float64

# %%
#removing unnecessary columns
air_bnb1 = air_bnb.drop(columns = ['host_has_profile_pic', 'host_identity_verified','latitude','longitude','thumbnail_url','zipcode'])
air_bnb1
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
#dealing with nulls
air_bnb2 = air_bnb1.fillna({'first_review':'ffill', 'last_review':'bfill', 'host_response_rate':'ffill', 'neighbourhood': 'null', 'review_scores_rating':'bfill'})
air_bnb2
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
air_bnb2.isnull().sum()
# Out:
# id                        0
# log_price                 0
# property_type             0
# room_type                 0
# amenities                 0
# accommodates              0
# bathrooms               200
# bed_type                  0
# cancellation_policy       0
# cleaning_fee              0
# city                      0
# description               0
# first_review              0
# host_response_rate        0
# host_since              188
# instant_bookable          0
# last_review               0
# name                      0
# neighbourhood             0
# number_of_reviews         0
# review_scores_rating      0
# bedrooms                 91
# beds                    131
# dtype: int64

# %%
airbnb = air_bnb2.dropna()
airbnb
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# ...

# %%
airbnb.isnull().sum()
# Out:
# id                      0
# log_price               0
# property_type           0
# room_type               0
# amenities               0
# accommodates            0
# bathrooms               0
# bed_type                0
# cancellation_policy     0
# cleaning_fee            0
# city                    0
# description             0
# first_review            0
# host_response_rate      0
# host_since              0
# instant_bookable        0
# last_review             0
# name                    0
# neighbourhood           0
# number_of_reviews       0
# review_scores_rating    0
# bedrooms                0
# beds                    0
# dtype: int64

# %%
airbnb['log_price'].value_counts()
# Out:
# log_price
# 5.010635    2713
# 4.605170    2680
# 4.317488    2028
# 5.298317    1906
# 3.912023    1905
#             ...
# 6.917706       1
# 7.021084       1
# 6.390241       1
# 7.456455       1
# 6.357842       1
# Name: count, Length: 766, dtype: int64

# %%
airbnb['property_type'].value_counts()
# Out:
# property_type
# Apartment             48610
# House                 16424
# Condominium            2650
# Townhouse              1683
# Loft                   1236
# Other                   600
# Guesthouse              497
# Bed & Breakfast         457
# Bungalow                365
# Villa                   178
# Dorm                    134
# Guest suite             123
# Camper/RV                93
# Timeshare                76
# Cabin                    71
# In-law                   71
# Hostel                   70
# Boutique hotel           69
# Boat                     65
# Serviced apartment       21
# Tent                     18
# Castle                   13
# Vacation home            11
# Yurt                      9
# Hut                       8
# Treehouse                 7
# Chalet                    6
# Earth House               4
# Tipi                      3
# Train                     2
# Cave                      2
# Casa particular           1
# ...

# %%
airbnb['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    41082
# Private room       30358
# Shared room         2139
# Name: count, dtype: int64

# %%
airbnb['room_type'].value_counts().plot(kind = 'pie' , figsize =(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
airbnb['amenities'].value_counts().head(10)
# Out:
# amenities
# {}                                                                                                                                                                                                                                                                                                                                                                            543
# {"translation missing: en.hosting_amenity_49","translation missing: en.hosting_amenity_50"}                                                                                                                                                                                                                                                                                   134
# ...

# %%
airbnb['accommodates'].value_counts()
# Out:
# accommodates
# 2     31577
# 4     12009
# 1      9315
# 3      7746
# 6      4959
# 5      3433
# 8      1790
# 7       944
# 10      700
# 16      299
# 9       270
# 12      264
# 14      104
# 11       79
# 15       54
# 13       36
# Name: count, dtype: int64

# %%
airbnb['bathrooms'].value_counts()
# Out:
# bathrooms
# 1.0    57797
# 2.0     7919
# 1.5     3793
# 2.5     1565
# 3.0     1066
# 3.5      429
# 4.0      286
# 0.5      209
# 0.0      195
# 4.5      116
# 5.0       72
# 8.0       41
# 5.5       39
# 6.0       24
# 6.5       12
# 7.0       10
# 7.5        6
# Name: count, dtype: int64

# %%
airbnb['bed_type'].value_counts()
# Out:
# bed_type
# Real Bed         71516
# Futon              744
# Pull-out Sofa      579
# Airbed             474
# Couch              266
# Name: count, dtype: int64

# %%
sns.countplot(y = 'bed_type', data = airbnb, palette = 'rocket')
# Out:
# <Axes: xlabel='count', ylabel='bed_type'>

# %%
airbnb['cancellation_policy'].value_counts()
# Out:
# cancellation_policy
# strict             32139
# flexible           22374
# moderate           18942
# super_strict_30      107
# super_strict_60       17
# Name: count, dtype: int64

# %%
sns.countplot(y = 'cancellation_policy', data = airbnb, palette = 'rocket')
# Out:
# <Axes: xlabel='count', ylabel='cancellation_policy'>

# %%
airbnb['cleaning_fee'].value_counts()
# Out:
# cleaning_fee
# True     54072
# False    19507
# Name: count, dtype: int64

# %%
airbnb['cleaning_fee'].value_counts().plot(kind = 'pie', figsize = (6,6))
# Out:
# <Axes: ylabel='count'>

# %%
airbnb['city'].value_counts()
# Out:
# city
# NYC        31998
# LA         22338
# SF          6406
# DC          5664
# Chicago     3715
# Boston      3458
# Name: count, dtype: int64

# %%
sns.countplot(y = 'city', data = airbnb, palette = 'rocket')
# Out:
# <Axes: xlabel='count', ylabel='city'>

# %%
airbnb['description'].value_counts()
# Out:
# description
# ...

# %%
airbnb['first_review'].value_counts()
# Out:
# first_review
# ffill         15740
# 2017-01-01      291
# 2017-01-22      249
# 2016-01-02      220
# 2017-01-02      210
#               ...
# 2013-11-29        1
# 2010-09-08        1
# 2009-06-07        1
# 2010-09-10        1
# 2010-12-01        1
# Name: count, Length: 2525, dtype: int64

# %%
airbnb['last_review'].value_counts()
# Out:
# last_review
# bfill         15709
# 2017-04-30     1341
# 2017-09-24     1273
# 2017-09-17     1206
# 2017-04-23     1023
#               ...
# 2014-09-24        1
# 2013-01-01        1
# 2014-12-29        1
# 2013-03-27        1
# 2013-12-28        1
# Name: count, Length: 1354, dtype: int64

# %%
airbnb['host_response_rate'].value_counts()
# Out:
# host_response_rate
# 100%     43089
# ffill    18021
# 90%       2270
# 80%       1111
# 0%         877
#          ...
# 39%          1
# 6%           1
# 15%          1
# 31%          1
# 21%          1
# Name: count, Length: 81, dtype: int64

# %%
airbnb['host_since'].value_counts()
# Out:
# host_since
# 2015-03-30    246
# 2014-02-14    173
# 2016-09-16     83
# 2015-05-18     83
# 2015-07-06     82
#              ...
# 2010-02-28      1
# 2008-12-31      1
# 2009-05-11      1
# 2009-09-04      1
# 2009-08-23      1
# Name: count, Length: 3079, dtype: int64

# %%
airbnb['instant_bookable'].value_counts()
# Out:
# instant_bookable
# f    54226
# t    19353
# Name: count, dtype: int64

# %%
airbnb['instant_bookable'].value_counts().plot(kind = 'pie', figsize =(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
airbnb['name'].value_counts()
# Out:
# name
# Bunk bed in the Treat Street Clubhouse             8
# Your home away from home                           7
# East Village Studio                                7
# Spacious Private Room in Brooklyn                  6
# Location, Location, Location                       6
#                                                   ..
# Private room w/shared bathroom at Sheridan Stop    1
# Quiet Cozy Room by Times Square - Female           1
# Spacious Master bedroom in a stunning community    1
# Brand new lux 1BR @ prime location!                1
# Cozy Boat at Shoreline Village                     1
# Name: count, Length: 72836, dtype: int64

# %%
airbnb['neighbourhood'].value_counts()
# Out:
# neighbourhood
# null                        6844
# Williamsburg                2841
# Bedford-Stuyvesant          2141
# Bushwick                    1587
# Mid-Wilshire                1386
#                             ...
# Suitland-Silver Hill, MD       1
# Graniteville                   1
# Pullman                        1
# West Town                      1
# Grant City                     1
# Name: count, Length: 620, dtype: int64

# %%
airbnb['number_of_reviews'].value_counts()
# Out:
# number_of_reviews
# 0      15701
# 1       7061
# 2       4718
# 3       3641
# 4       2895
#        ...
# 329        1
# 425        1
# 250        1
# 279        1
# 341        1
# Name: count, Length: 370, dtype: int64

# %%
airbnb['review_scores_rating'].value_counts()
# Out:
# review_scores_rating
# bfill    16590
# 100.0    16122
# 98.0      4343
# 97.0      4062
# 96.0      4060
# 95.0      3688
# 93.0      3621
# 90.0      2823
# 99.0      2619
# 94.0      2602
# 80.0      2143
# 92.0      2049
# 91.0      1605
# 87.0      1109
# 89.0      1104
# 88.0      1049
# 85.0       616
# 86.0       508
# 60.0       441
# 84.0       434
# 83.0       395
# 82.0       210
# 70.0       195
# 73.0       156
# 81.0       125
# 75.0        97
# 20.0        96
# 78.0        93
# 40.0        89
# 79.0        83
# 76.0        75
# 77.0        74
# 67.0        66
# 74.0        38
# 72.0        36
# 50.0        30
# 65.0        27
# 68.0        20
# 71.0        14
# 69.0        13
# 63.0        11
# 64.0        10
# 53.0        10
# 47.0         5
# 30.0         4
# 55.0         3
# 66.0         3
# 62.0         3
# 57.0         3
# 27.0         2
# 58.0         1
# 35.0         1
# 49.0         1
# 54.0         1
# 56.0         1
# Name: count, dtype: int64

# %%
airbnb['bedrooms'].value_counts()
# Out:
# bedrooms
# 1.0     49411
# 2.0     11316
# 0.0      6694
# 3.0      4301
# 4.0      1327
# 5.0       354
# 6.0       106
# 7.0        38
# 8.0        14
# 10.0       10
# 9.0         8
# Name: count, dtype: int64

# %%
airbnb['beds'].value_counts()
# Out:
# beds
# 1.0     44837
# 2.0     16631
# 3.0      6430
# 4.0      3059
# 5.0      1286
# 6.0       660
# 7.0       215
# 8.0       186
# 10.0       88
# 9.0        72
# 16.0       38
# 12.0       29
# 11.0       23
# 13.0       10
# 15.0        6
# 14.0        4
# 0.0         4
# 18.0        1
# Name: count, dtype: int64

# %%
airbnb.groupby('property_type')['bedrooms'].mean().sort_values(ascending = False)
# Out:
# property_type
# Villa                 2.112360
# Lighthouse            2.000000
# Vacation home         1.727273
# Treehouse             1.714286
# House                 1.654408
# Townhouse             1.614379
# Castle                1.538462
# Train                 1.500000
# Condominium           1.392075
# Chalet                1.333333
# Boat                  1.246154
# Loft                  1.164239
# Apartment             1.133902
# Other                 1.100000
# Bed & Breakfast       1.063457
# Dorm                  1.052239
# Island                1.000000
# Serviced apartment    1.000000
# Guest suite           0.975610
# Bungalow              0.958904
# Tent                  0.944444
# Hostel                0.914286
# Timeshare             0.828947
# Boutique hotel        0.826087
# Camper/RV             0.795699
# In-law                0.788732
# Guesthouse            0.752515
# Earth House           0.750000
# Cabin                 0.732394
# ...

# %%
airbnb.groupby('property_type')['beds'].mean().sort_values(ascending = False)
# Out:
# property_type
# Hostel                4.285714
# Tipi                  3.666667
# Dorm                  3.223881
# Vacation home         3.000000
# Villa                 2.769663
# Treehouse             2.571429
# Castle                2.461538
# Hut                   2.375000
# Boat                  2.215385
# House                 2.121529
# Townhouse             2.043969
# Chalet                2.000000
# Train                 2.000000
# Island                2.000000
# Lighthouse            2.000000
# Tent                  1.888889
# Camper/RV             1.870968
# Condominium           1.780000
# Other                 1.766667
# Loft                  1.744337
# Timeshare             1.684211
# Guesthouse            1.605634
# Bungalow              1.591781
# Guest suite           1.577236
# Apartment             1.550319
# Bed & Breakfast       1.527352
# In-law                1.507042
# Cave                  1.500000
# Cabin                 1.450704
# ...

# %%
airbnb.groupby('property_type')['accommodates'].mean().sort_values(ascending = False)
# Out:
# property_type
# Lighthouse            6.000000
# Vacation home         5.181818
# Villa                 5.112360
# Castle                4.846154
# Tipi                  4.666667
# Earth House           4.500000
# Other                 3.963333
# House                 3.762604
# Townhouse             3.755793
# Treehouse             3.714286
# Loft                  3.662621
# Timeshare             3.513158
# Train                 3.500000
# Hut                   3.500000
# Hostel                3.457143
# Condominium           3.427547
# Boat                  3.415385
# Serviced apartment    3.285714
# Tent                  3.277778
# Boutique hotel        3.260870
# Dorm                  3.216418
# Chalet                3.166667
# Camper/RV             3.150538
# Bungalow              2.956164
# Apartment             2.903826
# In-law                2.901408
# Guesthouse            2.877264
# Yurt                  2.777778
# Guest suite           2.764228
# ...

# %%
airbnb.groupby('property_type')['bathrooms'].mean().sort_values(ascending = False)
# Out:
# property_type
# Hostel                2.664286
# Dorm                  2.235075
# Villa                 2.095506
# Vacation home         1.818182
# Treehouse             1.571429
# Townhouse             1.546940
# Castle                1.538462
# House                 1.498113
# Condominium           1.329057
# Bed & Breakfast       1.270241
# Chalet                1.250000
# Loft                  1.221278
# Other                 1.173333
# Boat                  1.169231
# Timeshare             1.144737
# Apartment             1.129449
# Cabin                 1.119718
# Serviced apartment    1.095238
# Guest suite           1.089431
# Boutique hotel        1.086957
# Guesthouse            1.074447
# Bungalow              1.057534
# Tent                  1.055556
# In-law                1.042254
# Cave                  1.000000
# Lighthouse            1.000000
# Casa particular       1.000000
# Tipi                  1.000000
# Train                 1.000000
# ...

# %%
airbnb.groupby('name')['bedrooms'].mean().sort_values(ascending = False).head(10)
# Out:
# name
# 12 Bedroom House in heart of LA!                      10.0
# Loft Style 1 mile from Downtown Boston Brownstone.    10.0
# INCREDIBLE TOWNHOUSE 3 STORIES 10 BEDROOMS 6 BATH     10.0
# New Metropolitan Guest House - 新大都會藝術客居               10.0
# New 4-plex 12 br/8 ba @ La Cienega Villas by LAX      10.0
# NYC Private Group Stay (10 Bedrooms 4 Bathrooms)      10.0
# 10 Bedrms;26 beds; Sleep 29; 7 baths; 2 Kitchens      10.0
# Combo Apt UP to 40 People                             10.0
# Vacation Homes By JFK Aiprort                         10.0
# Sleep 30, HALF-BLOCK from Wrigley!                    10.0
# Name: bedrooms, dtype: float64

# %%
airbnb.groupby('name')['beds'].mean().sort_values(ascending = False)
# Out:
# name
# New York City House for Large Groups/ Brooklyn        18.0
# Double Unit - Downtown/Convention/Ocean/Tour BC287    16.0
# PodShare Venice! Opens April 1                        16.0
# Perfect Location! Cheap price - NO FURNITURE          16.0
# i don't know how to delete my listing                 16.0
#                                                       ...
# Luxury 1 bedroom apt. Downtown Brooklyn/Dumbo          1.0
# Stay at Midtown 45 in the heart of NYC!                0.0
# COZY PRIVATE Bedroom in 2Br Apt!                       0.0
# Posh Studio in Back Bay                                0.0
# Visit the Big Apple with Midtown 45!                   0.0
# Name: beds, Length: 72836, dtype: float64

# %%
airbnb.groupby('name')['accommodates'].mean().sort_values(ascending = False)
# Out:
# name
# Mediterranean Resort living in DTLA                  16.0
# Huge, Amazing Apartment Minutes to the City!         16.0
# Clean Amazing-12 people sleep for very low price     16.0
# Venice Shared Living                                 16.0
# Eclectic Arts District Gallery for Filming/Events    16.0
#                                                      ...
# Private Single Room                                   1.0
# Sunny 1 Private Bedroom close to Downtown LA          1.0
# Sunny 1 bed near Lake Merced                          1.0
# Sunny 1 bedroom In The Heart of NYC                   1.0
# Bushwick retreat                                      1.0
# Name: accommodates, Length: 72836, dtype: float64

# %%
airbnb.groupby('name')['bathrooms'].mean().sort_values(ascending = False)
# Out:
# name
# Private Room with Two Twin Beds                       8.0
# Beautiful shared room in Modern CoLiving space/4R     8.0
# Malibu Mansion w/Pool and Tennis                      8.0
# New 4-plex 12 br/8 ba @ La Cienega Villas by LAX      8.0
# Room with 2 single beds & shared bathroom in Hotel    8.0
#                                                      ...
# 温馨舒适雅房                                                0.0
# Cozy prvaite room｛温馨雅房｝                               0.0
# Cozy prvaite room 【温馨雅房】                              0.0
# 2 SUNNY RMs wparking in huge 3 bdrm                   0.0
# CUBS,DELUXE, CHIC TERRACED DUPLEX LOFT, TOP LOCALE    0.0
# Name: bathrooms, Length: 72836, dtype: float64

# %%
airbnb.groupby('city')['name'].count().sort_values(ascending = False)
# Out:
# city
# NYC        31998
# LA         22338
# SF          6406
# DC          5664
# Chicago     3715
# Boston      3458
# Name: name, dtype: int64

# %%
airbnb.groupby('city')['bedrooms'].mean().sort_values(ascending = False)
# Out:
# city
# Chicago    1.444953
# SF         1.349204
# Boston     1.344419
# LA         1.335751
# DC         1.332980
# NYC        1.161385
# Name: bedrooms, dtype: float64

# %%
airbnb.groupby('city')['beds'].mean().sort_values(ascending = False)
# Out:
# city
# Chicago    1.912786
# LA         1.866058
# DC         1.808969
# Boston     1.763447
# SF         1.716984
# NYC        1.559660
# Name: beds, dtype: float64

# %%
airbnb.groupby('city')['accommodates'].mean().sort_values(ascending = False)
# Out:
# city
# Chicago    3.815074
# DC         3.544668
# LA         3.412347
# Boston     3.304800
# SF         3.173899
# NYC        2.823301
# Name: accommodates, dtype: float64

# %%
airbnb.groupby('city')['bathrooms'].mean().sort_values(ascending = False)
# Out:
# city
# LA         1.351128
# DC         1.314972
# Chicago    1.283311
# SF         1.259913
# Boston     1.237131
# NYC        1.131336
# Name: bathrooms, dtype: float64

# %%
airbnb.groupby('room_type')['name'].count().sort_values(ascending = False)
# Out:
# room_type
# Entire home/apt    41082
# Private room       30358
# Shared room         2139
# Name: name, dtype: int64

# %%
airbnb.groupby('room_type')['bedrooms'].mean().sort_values(ascending = False)
# Out:
# room_type
# Entire home/apt    1.459082
# Private room       1.025397
# Shared room        1.000000
# Name: bedrooms, dtype: float64

# %%
airbnb.groupby('room_type')['beds'].mean().sort_values(ascending = False)
# Out:
# room_type
# Entire home/apt    2.110730
# Shared room        1.744741
# Private room       1.172475
# Name: beds, dtype: float64

# %%
airbnb.groupby('room_type')['accommodates'].mean().sort_values(ascending = False)
# Out:
# room_type
# Entire home/apt    4.083759
# Shared room        2.048621
# Private room       1.990381
# Name: accommodates, dtype: float64

# %%
airbnb.groupby('room_type')['bathrooms'].mean().sort_values(ascending = False)
# Out:
# room_type
# Shared room        1.341515
# Entire home/apt    1.308688
# Private room       1.130295
# Name: bathrooms, dtype: float64
