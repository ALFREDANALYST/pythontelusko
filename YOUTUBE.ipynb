# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set(color_codes=True)

# %%
#importing dataset
youtube_stats = pd.read_csv("E:/GOOGLE3/GlobalYouTubeStatistics.csv", encoding = 'latin1')
youtube_stats
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
youtube_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
youtube_stats.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
youtube_stats.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# ...

# %%
youtube_stats.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
youtube1 = youtube_stats.fillna({'subscribers_for_last_30_days' : '_'})
youtube1
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %%
youtube1.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days                 0
# created_year                                 5
# ...

# %%
youtube = youtube1.dropna()
youtube
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads        Country  \
# 0               Music                    T-Series    20082          India
# ...

# %%
youtube.isnull().sum()
# Out:
# rank                                       0
# Youtuber                                   0
# subscribers                                0
# video views                                0
# category                                   0
# Title                                      0
# uploads                                    0
# Country                                    0
# Abbreviation                               0
# channel_type                               0
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# lowest_monthly_earnings                    0
# highest_monthly_earnings                   0
# lowest_yearly_earnings                     0
# highest_yearly_earnings                    0
# subscribers_for_last_30_days               0
# created_year                               0
# created_month                              0
# ...

# %%
youtube.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 989    False
# 990    False
# 991    False
# 993    False
# 994    False
# Length: 808, dtype: bool

# %%
youtube.drop_duplicates()
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 989   990                   Migos ATL     12400000  6.993406e+09
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads        Country  \
# 0               Music                    T-Series    20082          India
# ...

# %%
youtube.describe()
# Out:
#              rank   subscribers   video views        uploads  \
# count  808.000000  8.080000e+02  8.080000e+02     808.000000
# mean   499.915842  2.312785e+07  1.155749e+10   11181.346535
# std    286.618745  1.831925e+07  1.522270e+10   37614.822861
# min      1.000000  1.230000e+07  0.000000e+00       1.000000
# 25%    253.500000  1.450000e+07  4.351711e+09     340.000000
# 50%    506.500000  1.760000e+07  7.891461e+09     983.500000
# 75%    745.250000  2.432500e+07  1.392057e+10    3658.750000
# max    995.000000  2.450000e+08  2.280000e+11  301308.000000
#
#        video_views_rank  country_rank  channel_type_rank  \
# count      8.080000e+02    808.000000         808.000000
# mean       1.666462e+05    253.100248         312.809406
# std        7.579997e+05    935.447025        1121.241477
# min        1.000000e+00      1.000000           1.000000
# 25%        2.777500e+02     11.000000          25.000000
# 50%        7.685000e+02     45.500000          59.500000
# ...

# %%
youtube['Youtuber'].nunique()
# Out:
# 808

# %%
youtube['subscribers'].sum()
# Out:
# 18687300000

# %%
youtube['subscribers'].mean()
# Out:
# 23127846.534653466

# %%
youtube['video views'].sum()
# Out:
# 9338453919965.0

# %%
youtube['video views'].mean()
# Out:
# 11557492475.204208

# %%
youtube['category'].nunique()
# Out:
# 18

# %%
youtube['category'].value_counts()
# Out:
# category
# Entertainment            208
# Music                    178
# People & Blogs           101
# Gaming                    79
# Comedy                    61
# Education                 41
# Film & Animation          34
# Howto & Style             32
# News & Politics           26
# Science & Technology      13
# Shows                     12
# Sports                    11
# Pets & Animals             3
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
youtube['Title'].nunique()
# Out:
# 806

# %%
youtube['uploads'].sum()
# Out:
# 9034528

# %%
youtube['uploads'].mean()
# Out:
# 11181.346534653465

# %%
youtube['Country'].nunique()
# Out:
# 47

# %%
youtube['Country'].value_counts()
# Out:
# Country
# United States           283
# India                   161
# Brazil                   60
# United Kingdom           42
# Mexico                   30
# Indonesia                27
# Spain                    21
# Thailand                 18
# Russia                   15
# South Korea              15
# Canada                   13
# Argentina                13
# Colombia                 11
# Philippines              10
# Saudi Arabia              8
# Australia                 8
# Ukraine                   8
# Germany                   5
# France                    5
# United Arab Emirates      5
# Japan                     5
# Pakistan                  4
# Turkey                    3
# Chile                     3
# Vietnam                   3
# Jordan                    3
# Netherlands               3
# Sweden                    3
# Egypt                     2
# Ecuador                   2
# Iraq                      2
# Italy                     2
# Finland                   1
# ...

# %%
youtube['channel_type'].nunique()
# Out:
# 14

# %%
youtube['channel_type'].value_counts()
# Out:
# channel_type
# Entertainment    269
# Music            193
# Games             73
# People            57
# Comedy            46
# Education         44
# Film              34
# Howto             31
# News              29
# Tech              14
# Sports            11
# Animals            3
# Nonprofit          2
# Autos              2
# Name: count, dtype: int64

# %%
youtube['created_year'].value_counts()
# Out:
# created_year
# 2014.0    94
# 2011.0    76
# 2006.0    71
# 2015.0    66
# 2013.0    65
# 2016.0    59
# 2012.0    59
# 2017.0    52
# 2009.0    49
# 2007.0    42
# 2008.0    41
# 2010.0    40
# 2018.0    28
# 2005.0    20
# 2020.0    18
# 2019.0    14
# 2021.0    12
# 1970.0     1
# 2022.0     1
# Name: count, dtype: int64

# %%
youtube['created_month'].value_counts()
# Out:
# created_month
# Jan    90
# Sep    86
# Jul    73
# May    71
# Nov    69
# Oct    67
# Mar    66
# Aug    65
# Apr    57
# Feb    56
# Jun    56
# Dec    52
# Name: count, dtype: int64

# %%
youtube['created_date'].value_counts()
# Out:
# created_date
# 9.0     38
# 26.0    36
# 22.0    36
# 6.0     35
# 8.0     34
# 19.0    33
# 1.0     31
# 2.0     31
# 20.0    30
# 15.0    30
# 12.0    29
# 14.0    29
# 4.0     29
# 13.0    27
# 24.0    26
# 27.0    26
# 21.0    25
# 16.0    25
# 29.0    25
# 30.0    24
# 18.0    22
# 17.0    22
# 25.0    21
# 5.0     21
# 23.0    20
# 7.0     19
# 28.0    19
# 3.0     18
# 11.0    17
# 31.0    15
# 10.0    15
# Name: count, dtype: int64

# %%
#country
youtube.groupby('Country')['Youtuber'].count().sort_values(ascending = False)
# Out:
# Country
# United States           283
# India                   161
# Brazil                   60
# United Kingdom           42
# Mexico                   30
# Indonesia                27
# Spain                    21
# Thailand                 18
# Russia                   15
# South Korea              15
# Argentina                13
# Canada                   13
# Colombia                 11
# Philippines              10
# Ukraine                   8
# Saudi Arabia              8
# Australia                 8
# France                    5
# Germany                   5
# United Arab Emirates      5
# Japan                     5
# Pakistan                  4
# Sweden                    3
# Turkey                    3
# Netherlands               3
# Vietnam                   3
# Jordan                    3
# Chile                     3
# Ecuador                   2
# Italy                     2
# Iraq                      2
# Egypt                     2
# Morocco                   1
# ...

# %%
youtube.groupby('Country')['subscribers'].sum().sort_values(ascending = False)
# Out:
# Country
# United States           6702000000
# India                   4211900000
# Brazil                  1194900000
# United Kingdom           905100000
# Mexico                   553600000
# Indonesia                520900000
# South Korea              446300000
# Russia                   391300000
# Thailand                 386500000
# Spain                    368500000
# Argentina                328500000
# Canada                   320200000
# Colombia                 264500000
# Philippines              209900000
# Japan                    189100000
# Australia                154400000
# Saudi Arabia             153000000
# Pakistan                 129900000
# Ukraine                  125600000
# United Arab Emirates     102300000
# Germany                   95000000
# Chile                     87200000
# France                    83900000
# Jordan                    67000000
# Turkey                    58900000
# Netherlands               58100000
# ...

# %%
youtube.groupby('Country')['video views'].sum().sort_values(ascending = False)
# Out:
# Country
# United States           3.415507e+12
# India                   2.268187e+12
# Brazil                  4.761656e+11
# United Kingdom          4.283518e+11
# Thailand                2.643180e+11
# Russia                  2.311510e+11
# South Korea             1.989974e+11
# Argentina               1.944154e+11
# Canada                  1.778355e+11
# Mexico                  1.771090e+11
# Colombia                1.541978e+11
# Indonesia               1.468050e+11
# Spain                   1.288238e+11
# Philippines             1.269127e+11
# Pakistan                1.086517e+11
# Japan                   8.568202e+10
# Turkey                  7.321920e+10
# Saudi Arabia            7.178054e+10
# Australia               6.538947e+10
# Ukraine                 5.846533e+10
# Jordan                  5.309008e+10
# Germany                 5.265919e+10
# United Arab Emirates    5.108863e+10
# France                  3.055764e+10
# Chile                   2.934756e+10
# ...

# %%
youtube.groupby('Country')['uploads'].sum().sort_values(ascending = False)
# Out:
# Country
# India                   3726099
# United States           1287940
# Thailand                 858953
# Philippines              838090
# Indonesia                676997
# Pakistan                 507702
# Ukraine                  220128
# United Arab Emirates     172827
# Brazil                   168169
# South Korea              126190
# United Kingdom            84364
# Spain                     69944
# Canada                    46744
# Mexico                    33410
# Singapore                 31889
# Turkey                    25451
# Russia                    19558
# Japan                     18856
# Argentina                 17240
# Netherlands               14329
# Saudi Arabia              13107
# Colombia                  10779
# Switzerland               10728
# Australia                  7179
# Chile                      6771
# Germany                    6743
# Jordan                     6667
# Egypt                      5936
# Vietnam                    5408
# ...

# %%
youtube.groupby('Country')['Gross tertiary education enrollment (%)'].mean().sort_values(ascending = False)
# Out:
# Country
# Australia               113.1
# South Korea              94.3
# Argentina                90.0
# Spain                    88.9
# Chile                    88.5
# Finland                  88.2
# United States            88.2
# Latvia                   88.1
# Netherlands              85.0
# Singapore                84.8
# Ukraine                  82.7
# Russia                   81.9
# Venezuela                79.3
# Peru                     70.7
# Germany                  70.2
# Canada                   68.9
# Saudi Arabia             68.0
# Sweden                   67.0
# France                   65.6
# Barbados                 65.4
# Japan                    63.2
# Italy                    61.9
# United Kingdom           60.0
# Switzerland              59.6
# Colombia                 55.3
# Kuwait                   54.4
# Brazil                   51.3
# China                    50.6
# Thailand                 49.3
# Malaysia                 45.1
# ...

# %%
youtube.groupby('Country')['Population'].mean().sort_values(ascending = False)
# Out:
# Country
# China                   1.397715e+09
# India                   1.366418e+09
# United States           3.282395e+08
# Indonesia               2.702039e+08
# Pakistan                2.165653e+08
# Brazil                  2.125594e+08
# Bangladesh              1.673108e+08
# Russia                  1.443735e+08
# Japan                   1.262266e+08
# Mexico                  1.260140e+08
# Philippines             1.081166e+08
# Egypt                   1.003881e+08
# Vietnam                 9.646211e+07
# Turkey                  8.342962e+07
# Germany                 8.313280e+07
# Thailand                6.962558e+07
# France                  6.705989e+07
# United Kingdom          6.683440e+07
# Italy                   6.029740e+07
# South Korea             5.170910e+07
# Colombia                5.033944e+07
# Spain                   4.707678e+07
# Argentina               4.493871e+07
# Ukraine                 4.438516e+07
# Iraq                    3.930978e+07
# ...

# %%
youtube.groupby('Country')['Unemployment rate'].mean().sort_values(ascending = False)
# Out:
# Country
# Jordan                  14.72
# United States           14.70
# Spain                   13.96
# Turkey                  13.49
# Iraq                    12.82
# Brazil                  12.08
# Egypt                   10.76
# Barbados                10.33
# Italy                    9.89
# Argentina                9.79
# Colombia                 9.71
# Morocco                  9.02
# Ukraine                  8.88
# Venezuela                8.80
# France                   8.43
# Samoa                    8.36
# Chile                    7.09
# Finland                  6.59
# Latvia                   6.52
# Sweden                   6.48
# Saudi Arabia             5.93
# Canada                   5.56
# India                    5.36
# Australia                5.27
# Indonesia                4.69
# Russia                   4.59
# Switzerland              4.58
# Pakistan                 4.45
# China                    4.32
# Bangladesh               4.19
# ...

# %%
youtube.groupby('Country')['Urban_population'].mean().sort_values(ascending = False)
# Out:
# Country
# China                   842933962.0
# India                   471031528.0
# United States           270663028.0
# Brazil                  183241641.0
# Indonesia               151509724.0
# Japan                   115782416.0
# Russia                  107683889.0
# Mexico                  102626859.0
# Pakistan                 79927762.0
# Germany                  64324835.0
# Turkey                   63097818.0
# Bangladesh               60987417.0
# United Kingdom           55908316.0
# France                   54123364.0
# Philippines              50975903.0
# Egypt                    42895824.0
# Italy                    42651966.0
# South Korea              42106719.0
# Argentina                41339571.0
# Colombia                 40827302.0
# Spain                    37927409.0
# Vietnam                  35332140.0
# Thailand                 35294600.0
# Ukraine                  30835699.0
# Canada                   30628482.0
# Saudi Arabia             28807838.0
# ...

# %%
#category
youtube.groupby('category')['Youtuber'].count().sort_values(ascending = False)
# Out:
# category
# Entertainment            208
# Music                    178
# People & Blogs           101
# Gaming                    79
# Comedy                    61
# Education                 41
# Film & Animation          34
# Howto & Style             32
# News & Politics           26
# Science & Technology      13
# Shows                     12
# Sports                    11
# Pets & Animals             3
# Trailers                   2
# Autos & Vehicles           2
# Nonprofits & Activism      2
# Movies                     2
# Travel & Events            1
# Name: Youtuber, dtype: int64

# %%
youtube.groupby('category')['subscribers'].sum().sort_values(ascending = False)
# Out:
# category
# Music                    4613300000
# Entertainment            4474100000
# People & Blogs           2203900000
# Gaming                   1601700000
# Comedy                   1204100000
# Education                1125500000
# Film & Animation          959400000
# Howto & Style             607500000
# News & Politics           536400000
# Shows                     522100000
# Sports                    298200000
# Science & Technology      249900000
# Trailers                   78000000
# Pets & Animals             58200000
# Nonprofits & Activism      55500000
# Movies                     51300000
# Autos & Vehicles           35700000
# Travel & Events            12500000
# Name: subscribers, dtype: int64

# %%
youtube.groupby('category')['video views'].sum().sort_values(ascending = False)
# Out:
# category
# Music                    2.782738e+12
# Entertainment            2.223126e+12
# People & Blogs           1.007894e+12
# Education                6.773961e+11
# Gaming                   6.040682e+11
# Comedy                   4.672097e+11
# Shows                    4.379051e+11
# Film & Animation         4.148976e+11
# News & Politics          2.703919e+11
# Howto & Style            1.499354e+11
# Sports                   1.479863e+11
# Science & Technology     4.235005e+10
# Pets & Animals           3.490263e+10
# Trailers                 3.326272e+10
# Movies                   1.538326e+10
# Autos & Vehicles         1.500346e+10
# Nonprofits & Activism    1.086291e+10
# Travel & Events          3.140883e+09
# Name: video views, dtype: float64

# %%
youtube.groupby("category")['uploads'].sum().sort_values(ascending = False)
# Out:
# category
# News & Politics          2924594
# Entertainment            2863599
# People & Blogs           1200966
# Music                     465427
# Gaming                    388256
# Shows                     356768
# Nonprofits & Activism     205824
# Sports                    159431
# Education                 141321
# Film & Animation          114593
# Comedy                     76922
# Howto & Style              60603
# Science & Technology       33079
# Pets & Animals             17798
# Trailers                   13678
# Movies                      7106
# Autos & Vehicles            3797
# Travel & Events              766
# Name: uploads, dtype: int64

# %%
youtube.groupby('category')['Country'].count().sort_values(ascending = False)
# Out:
# category
# Entertainment            208
# Music                    178
# People & Blogs           101
# Gaming                    79
# Comedy                    61
# Education                 41
# Film & Animation          34
# Howto & Style             32
# News & Politics           26
# Science & Technology      13
# Shows                     12
# Sports                    11
# Pets & Animals             3
# Trailers                   2
# Autos & Vehicles           2
# Nonprofits & Activism      2
# Movies                     2
# Travel & Events            1
# Name: Country, dtype: int64
