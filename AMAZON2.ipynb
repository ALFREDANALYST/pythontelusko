# %%
import pandas as pd
import numpy as np

# %%
amazon_products = pd.read_csv("E:/PYTHON PROJECTS/amazon_products.csv")
amazon_products
# Out:
#                asin                                              title  \
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl  \
# ...

# %%
amazon_categories = pd.read_csv("E:/PYTHON PROJECTS/amazon_categories.csv")
amazon_categories
# Out:
#       id                                    category_name
# 0      1                         Beading & Jewelry Making
# 1      2                                Fabric Decorating
# 2      3                      Knitting & Crochet Supplies
# 3      4                             Printmaking Supplies
# 4      5                 Scrapbooking & Stamping Supplies
# ..   ...                                              ...
# 243  262  Xbox Series X & S Consoles, Games & Accessories
# 244  263                           PC Games & Accessories
# 245  264                     Baby Girls' Clothing & Shoes
# 246  265                            Boys' School Uniforms
# 247  270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
#analysis of amazon_products dataset
amazon_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426337 entries, 0 to 1426336
# Data columns (total 11 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   asin               1426337 non-null  object
#  1   title              1426336 non-null  object
#  2   imgUrl             1426337 non-null  object
#  3   productURL         1426337 non-null  object
#  4   stars              1426337 non-null  float64
#  5   reviews            1426337 non-null  int64
#  6   price              1426337 non-null  float64
#  7   listPrice          1426337 non-null  float64
#  8   category_id        1426337 non-null  int64
#  9   isBestSeller       1426337 non-null  bool
#  10  boughtInLastMonth  1426337 non-null  int64
# dtypes: bool(1), float64(3), int64(3), object(4)
# memory usage: 110.2+ MB

# %%
amazon_products.dtypes
# Out:
# asin                  object
# title                 object
# imgUrl                object
# productURL            object
# stars                float64
# reviews                int64
# price                float64
# listPrice            float64
# category_id            int64
# isBestSeller            bool
# boughtInLastMonth      int64
# dtype: object

# %%
amazon_products.isnull().sum()
# Out:
# asin                 0
# title                1
# imgUrl               0
# productURL           0
# stars                0
# reviews              0
# price                0
# listPrice            0
# category_id          0
# isBestSeller         0
# boughtInLastMonth    0
# dtype: int64

# %%
amazon_products.drop_duplicates()
# Out:
#                asin                                              title  \
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl  \
# ...

# %%
amazon_products.describe()
# Out:
#               stars       reviews         price     listPrice   category_id  \
# count  1.426337e+06  1.426337e+06  1.426337e+06  1.426337e+06  1.426337e+06
# mean   3.999512e+00  1.807508e+02  4.337540e+01  1.244916e+01  1.237409e+02
# std    1.344292e+00  1.761453e+03  1.302893e+02  4.611198e+01  7.311273e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# 25%    4.100000e+00  0.000000e+00  1.199000e+01  0.000000e+00  6.500000e+01
# 50%    4.400000e+00  0.000000e+00  1.995000e+01  0.000000e+00  1.200000e+02
# 75%    4.600000e+00  0.000000e+00  3.599000e+01  0.000000e+00  1.760000e+02
# max    5.000000e+00  3.465630e+05  1.973181e+04  9.999900e+02  2.700000e+02
#
#        boughtInLastMonth
# count       1.426337e+06
# mean        1.419823e+02
# std         8.362720e+02
# min         0.000000e+00
# 25%         0.000000e+00
# 50%         0.000000e+00
# 75%         5.000000e+01
# max         1.000000e+05

# %%
#analysis of amazon_categories dataset
amazon_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             248 non-null    int64
#  1   category_name  248 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 4.0+ KB

# %%
amazon_categories.drop_duplicates()
# Out:
#       id                                    category_name
# 0      1                         Beading & Jewelry Making
# 1      2                                Fabric Decorating
# 2      3                      Knitting & Crochet Supplies
# 3      4                             Printmaking Supplies
# 4      5                 Scrapbooking & Stamping Supplies
# ..   ...                                              ...
# 243  262  Xbox Series X & S Consoles, Games & Accessories
# 244  263                           PC Games & Accessories
# 245  264                     Baby Girls' Clothing & Shoes
# 246  265                            Boys' School Uniforms
# 247  270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
amazon_products['category_id']
# Out:
# 0          104
# 1          104
# 2          104
# 3          104
# 4          104
#           ...
# 1426332    112
# 1426333    112
# 1426334    112
# 1426335    112
# 1426336    112
# Name: category_id, Length: 1426337, dtype: int64

# %%
# renaming id column to category_id and joining datasets

amazon_categories1 = amazon_categories.rename(columns={'id':'category_id'})

amazon_categories1
# Out:
#      category_id                                    category_name
# 0              1                         Beading & Jewelry Making
# 1              2                                Fabric Decorating
# 2              3                      Knitting & Crochet Supplies
# 3              4                             Printmaking Supplies
# 4              5                 Scrapbooking & Stamping Supplies
# ..           ...                                              ...
# 243          262  Xbox Series X & S Consoles, Games & Accessories
# 244          263                           PC Games & Accessories
# 245          264                     Baby Girls' Clothing & Shoes
# 246          265                            Boys' School Uniforms
# 247          270                                     Toys & Games
#
# [248 rows x 2 columns]

# %%
#merging tables
amazon = amazon_products.merge(amazon_categories1, how = 'left', on = 'category_id')
amazon
# Out:
#                asin                                              title  \
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl  \
# ...

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1426337 entries, 0 to 1426336
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   asin               1426337 non-null  object
#  1   title              1426336 non-null  object
#  2   imgUrl             1426337 non-null  object
#  3   productURL         1426337 non-null  object
#  4   stars              1426337 non-null  float64
#  5   reviews            1426337 non-null  int64
#  6   price              1426337 non-null  float64
#  7   listPrice          1426337 non-null  float64
#  8   category_id        1426337 non-null  int64
#  9   isBestSeller       1426337 non-null  bool
#  10  boughtInLastMonth  1426337 non-null  int64
#  11  category_name      1426337 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(5)
# memory usage: 121.1+ MB

# %%
amazon.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1426332    False
# 1426333    False
# 1426334    False
# 1426335    False
# 1426336    False
# Length: 1426337, dtype: bool

# %%
amazon.drop_duplicates()
# Out:
#                asin                                              title  \
# 0        B014TMV5YE  Sion Softside Expandable Roller Luggage, Black...
# 1        B07GDLCQXV  Luggage Sets Expandable PC+ABS Durable Suitcas...
# 2        B07XSCCZYG  Platinum Elite Softside Expandable Checked Lug...
# 3        B08MVFKGJM  Freeform Hardside Expandable with Double Spinn...
# 4        B01DJLKZBA  Winfield 2 Hardside Expandable Luggage with Sp...
# ...             ...                                                ...
# 1426332  B00R3LIKCO  American Flag Patriotic USA Classic 5 Panel Me...
# 1426333  B098BQ7ZQ3  Men's Baseball Cap - H2O-DRI Line Up Curved Br...
# 1426334  B07X1MVNT1  [4 Pack] Adjustable Eyeglasses and Sunglasses ...
# 1426335  B08XLBG8V9                          Ax2002 Aviator Sunglasses
# 1426336  B07GH67QC8  in Hoc Signo Vinces Knights Templar Masonic Em...
#
#                                                     imgUrl  \
# ...

# %%
amazon.columns
# Out:
# Index(['asin', 'title', 'imgUrl', 'productURL', 'stars', 'reviews', 'price',
#        'listPrice', 'category_id', 'isBestSeller', 'boughtInLastMonth',
#        'category_name'],
#       dtype='object')

# %%
amazon['asin'].nunique()
# Out:
# 1426337

# %%
amazon['title'].nunique()
# Out:
# 1385430

# %%
amazon['title'].value_counts().head(20)
# Out:
# title
# Men's Sneaker                                                                                                                                                                                            89
# mens Modern                                                                                                                                                                                              86
# Men's Ultraboost 23 Running Shoe                                                                                                                                                                         83
# Sleep and Play PJs, 100% Organic Cotton One-Piece Zip Front Romper Jumpsuit Pajamas                                                                                                                      77
# ...

# %%
amazon.groupby('title')['stars'].mean().sort_values(ascending = False).head(20)
# Out:
# title
# MroMax 100Pcs Small Screw Eye Hooks 1.18" Length Galvanized Iron Screw-in Hanger Eye-Shape Ring Hooks 30mm Self Tapping Screws for Home Office Hanging Plants Blue Tone                                    5.0
# Cartoon Baby Birthday Boxes 16pcs, Tropical Ocean Birthday Party Supplies 2 Designs Candy Boxes Cake Boxes Goodie Gift Boxes with Handles for Cartoon Birthday Party Favors, 6 x 3.5 x 3.5 In              5.0
# Cartoon 3D Figure Kids Backpack For Girls Boys 16.5in Large Capacity Bag Lightweight Waterproof Laptop Backpack Casual Travel Bags Daypack Cosplay for Movie Fans Gifts(Red)                               5.0
# Cartoon 3Pcs Backpack Set Lightweight Laptop Backpack with Lunch Bag Pencil Case 17in Casual Daypack Travel Bag                                                                                            5.0
# ...

# %%
amazon.groupby('title')['reviews'].sum().sort_values(ascending = False).head(10)
# Out:
# title
# essence | Lash Princess False Lash Effect Mascara | Gluten & Cruelty Free                                                                                                                                   346563
# ThisWorx Cordless Car Vacuum - Portable, Mini Handheld Vacuum w/Rechargeable Battery and 3 Attachments - High-Powered Vacuum Cleaner w/ 60w Motor                                                           292474
# Queen Size Sheet Set - Breathable & Cooling Sheets - Hotel Luxury Bed Sheets for Women, Men Kids & Teens - Deep Pockets - 4 Piece Set - Soft & Wrinkle Free - Off White Bed Sheets - Comfy Queen Sheets     281661
# Queen Size Sheet Set - Breathable & Cooling Sheets - Hotel Luxury Bed Sheets for Women, Men Kids & Teens - Deep Pockets - 4 Piece Set - Soft & Wrinkle Free - Spa Blue Bed Sheets - Queen Sheets - 4PC      281661
# ...

# %%
amazon.groupby('title')['price'].sum().sort_values(ascending = False).head(10)
# Out:
# title
# Overland Storage Neoxl80 Storagelibrary Lto8 SAS                                                       19731.81
# replicas Marinas                                                                                       19400.00
# CISCO Systems 1 Port ATM Enhanced Oc12/Stm4 Single Mode Intermediate Reach                             16468.70
# Cisco Systems 7140 Router Dual 10/100 Fe Dual Ac IP Sw                                                 12629.66
# PARTNERS BRAND Corrugated Trash Can Plain - 40 Gallon                                                  12519.96
# Sony VPL-XW6000ES 4K HDR Laser Home Theater Projector with Native 4K SXRD Panel, White                 11998.00
# HPE MSA 2062 10GBASE-T iSCSI SFF Storage                                                               11214.12
# CISCO Systems Catalyst 5000 Family Supervisor Iii with Enhanced Nffc Ii                                10859.09
# ...

# %%
amazon['category_id'].nunique()
# Out:
# 248

# %%
amazon.groupby('category_name')['category_name'].count().sort_values(ascending = False).head(10)
# Out:
# category_name
# Girls' Clothing      28619
# Boys' Clothing       24660
# Toys & Games         20846
# Men's Shoes          19822
# Women's Handbags     18994
# Girls' Jewelry       18514
# Men's Clothing       18258
# Men's Accessories    17679
# Women's Clothing     17393
# Women's Jewelry      17005
# Name: category_name, dtype: int64

# %%
amazon.groupby('title')['boughtInLastMonth'].sum().sort_values(ascending = False).head(10)
# Out:
# title
# Neutrogena Cleansing Fragrance Free Makeup Remover Face Wipes, Cleansing Facial Towelettes for Waterproof Makeup, Alcohol-Free, Unscented, 100% Plant-Based Fibers, Twin Pack, 2 x 25 ct               108000
# Stardrops - The Pink Stuff - The Miracle All Purpose Cleaning Paste                                                                                                                                    100000
# COSRX Snail Mucin 96% Power Repairing Essence 3.38 fl.oz 100ml, Hydrating Serum for Face with Snail Secretion Filtrate for Dull & Damaged Skin, Not Tested on Animals, No Parabens, Korean Skincare    100000
# LMNT Zero-Sugar Electrolytes - Variety Salt - Hydration Powder Packets | No Artificial Ingredients | Keto & Paleo Friendly | 12 Sticks                                                                 100000
# ...

# %%
amazon.groupby('category_name')['stars'].mean().sort_values(ascending = False).head(10)
# Out:
# category_name
# Gift Cards                           4.832374
# Health & Household                   4.567541
# Industrial & Scientific              4.554726
# Household Supplies                   4.545314
# Kitchen & Dining                     4.544674
# Food Service Equipment & Supplies    4.522902
# Electrical Equipment                 4.518131
# Power Tools & Hand Tools             4.502181
# Sports & Outdoors                    4.499774
# Electronic Components                4.487720
# Name: stars, dtype: float64

# %%
amazon.groupby('category_name')['reviews'].sum().sort_values(ascending = False).head(10)
# Out:
# category_name
# Home Décor Products                17372441
# Makeup                             14429795
# Foot, Hand & Nail Care Products    14086149
# Televisions & Video Products       13269924
# Video Games                        12085813
# Girls' Clothing                    10866752
# Cat Supplies                       10573445
# Toys & Games                       10020872
# Headphones & Earbuds                9563968
# Wellness & Relaxation Products      9183758
# Name: reviews, dtype: int64

# %%
amazon.groupby('category_name')['price'].sum().sort_values(ascending = False).head(10)
# Out:
# category_name
# Computers & Tablets                           4553201.97
# Men's Shoes                                   1855241.35
# Men's Watches                                 1581441.04
# Women's Shoes                                 1181527.85
# Women's Handbags                              1060822.95
# Office Electronics                            1041131.99
# Automotive Performance Parts & Accessories    1007091.35
# Camera & Photo                                 990594.70
# Computers                                      943934.28
# Data Storage                                   943679.96
# Name: price, dtype: float64

# %%
amazon.groupby('category_name')['boughtInLastMonth'].sum().sort_values(ascending = False).head(10)
# Out:
# category_name
# Kitchen & Dining               10432300
# Hair Care Products              8012850
# Industrial & Scientific         7093350
# Household Cleaning Supplies     6875700
# Skin Care Products              6612150
# Health & Household              6138000
# Toys & Games                    5858000
# Home Storage & Organization     5356200
# Dog Supplies                    4576650
# Household Supplies              4289000
# Name: boughtInLastMonth, dtype: int64

# %%
amazon['isBestSeller'].value_counts()
# Out:
# isBestSeller
# False    1417817
# True        8520
# Name: count, dtype: int64
