# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
df = pd.read_csv("D:/Downloads/education_districtwise.csv")
df.head(10)
# Out:
#       DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI
# 0   DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1  DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2  DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3  DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4  DISTRICT486   STATE1       8       359        64    570060.0       65.00
# 5  DISTRICT323   STATE1      12       523        96   1070144.0       64.32
# 6  DISTRICT114   STATE1       6       110        49    147104.0       80.48
# 7  DISTRICT438   STATE1       7       134        54    143388.0       74.49
# 8  DISTRICT610   STATE1      10       388        80    409576.0       65.97
# 9  DISTRICT476   STATE1      11       361        86    555357.0       69.90

# %%
df.describe(include='all')
# Out:
#           DISTNAME STATNAME      BLOCKS     VILLAGES    CLUSTERS  \
# count          680      680  680.000000   680.000000  680.000000
# unique         680       36         NaN          NaN         NaN
# top     DISTRICT32  STATE21         NaN          NaN         NaN
# freq             1       75         NaN          NaN         NaN
# mean           NaN      NaN   10.760294   874.614706  121.226471
# std            NaN      NaN    9.585360   622.711657   94.040172
# min            NaN      NaN    1.000000     6.000000    1.000000
# 25%            NaN      NaN    5.000000   390.750000   56.750000
# 50%            NaN      NaN    8.000000   785.500000  101.000000
# 75%            NaN      NaN   13.000000  1204.250000  162.500000
# max            NaN      NaN   66.000000  3963.000000  592.000000
#
#           TOTPOPULAT  OVERALL_LI
# count   6.340000e+02  634.000000
# unique           NaN         NaN
# top              NaN         NaN
# freq             NaN         NaN
# ...

# %%
df['OVERALL_LI'].describe()
# Out:
# count    634.000000
# mean      73.395189
# std       10.098460
# min       37.220000
# 25%       66.437500
# 50%       73.490000
# 75%       80.815000
# max       98.760000
# Name: OVERALL_LI, dtype: float64

# %%
df['STATNAME'].describe()
# Out:
# count         680
# unique         36
# top       STATE21
# freq           75
# Name: STATNAME, dtype: object

# %%
#RangeOVERALL_LI
Range_OVERALL_LI = df['OVERALL_LI'].max() - df['OVERALL_LI'].min()
Range_OVERALL_LI
# Out:
# 61.540000000000006

# %%
df2 = pd.read_csv("D:/Downloads/c4_epa_air_quality.csv")
df2
# Out:
#      Unnamed: 0  date_local            state_name           county_name  \
# 0             0  2018-01-01               Arizona              Maricopa
# 1             1  2018-01-01                  Ohio               Belmont
# 2             2  2018-01-01               Wyoming                 Teton
# 3             3  2018-01-01          Pennsylvania          Philadelphia
# 4             4  2018-01-01                  Iowa                  Polk
# ..          ...         ...                   ...                   ...
# 255         255  2018-01-01  District Of Columbia  District of Columbia
# 256         256  2018-01-01             Wisconsin                 Dodge
# 257         257  2018-01-01              Kentucky             Jefferson
# 258         258  2018-01-01              Nebraska               Douglas
# 259         259  2018-01-01        North Carolina                  Wake
#
#          city_name                                    local_site_name  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        260 non-null    int64
#  1   date_local        260 non-null    object
#  2   state_name        260 non-null    object
#  3   county_name       260 non-null    object
#  4   city_name         260 non-null    object
#  5   local_site_name   257 non-null    object
#  6   parameter_name    260 non-null    object
#  7   units_of_measure  260 non-null    object
#  8   arithmetic_mean   260 non-null    float64
#  9   aqi               260 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 20.4+ KB

# %%
df2.isna().sum()
# Out:
# Unnamed: 0          0
# date_local          0
# state_name          0
# county_name         0
# city_name           0
# local_site_name     3
# parameter_name      0
# units_of_measure    0
# arithmetic_mean     0
# aqi                 0
# dtype: int64

# %%
df2.describe(include='all')
# Out:
#         Unnamed: 0  date_local  state_name  county_name      city_name  \
# count   260.000000         260         260          260            260
# unique         NaN           1          52          149            190
# top            NaN  2018-01-01  California  Los Angeles  Not in a city
# freq           NaN         260          66           14             21
# mean    129.500000         NaN         NaN          NaN            NaN
# std      75.199734         NaN         NaN          NaN            NaN
# min       0.000000         NaN         NaN          NaN            NaN
# 25%      64.750000         NaN         NaN          NaN            NaN
# 50%     129.500000         NaN         NaN          NaN            NaN
# 75%     194.250000         NaN         NaN          NaN            NaN
# max     259.000000         NaN         NaN          NaN            NaN
#
#        local_site_name   parameter_name   units_of_measure  arithmetic_mean  \
# ...

# %%
df2['state_name'].describe()
# Out:
# count            260
# unique            52
# top       California
# freq              66
# Name: state_name, dtype: object

# %%
df2['aqi'].median()
# Out:
# 5.0

# %%
df['OVERALL_LI'].hist()
# Out:
# <Axes: >

# %%
#mean literacy
mean_overall_li = df['OVERALL_LI'].mean()
mean_overall_li
# Out:
# np.float64(73.39518927444796)

# %%
#median literacy
std_overall_li = df['OVERALL_LI'].std()
std_overall_li
# Out:
# 10.098460413782469

# %%
#compute the actual percentage of district literacy rates that fall within +/- 1 SD from the mean.
lower_limit = mean_overall_li - 1 * std_overall_li
upper_limit = mean_overall_li + 1 * std_overall_li
((df['OVERALL_LI'] >= lower_limit) & (df['OVERALL_LI'] <= upper_limit)).mean()
# Out:
# np.float64(0.6191176470588236)

# %%
#percentage of values +/- 2 SD from mean
lower_limit = mean_overall_li - 2 * std_overall_li
upper_limit = mean_overall_li + 2 * std_overall_li
((df['OVERALL_LI'] >= lower_limit) & (df['OVERALL_LI'] <= upper_limit)).mean()
# Out:
# np.float64(0.8897058823529411)

# %%
#percentage of values +/- 3 SD from mean
lower_limit = mean_overall_li - 3 * std_overall_li
upper_limit = mean_overall_li + 3 * std_overall_li
((df['OVERALL_LI'] >= lower_limit) & (df['OVERALL_LI'] <= upper_limit)).mean()
# Out:
# np.float64(0.9294117647058824)

# %%
#comoute z-scores to find outliers
df['Z_SCORE'] = stats.zscore(df['OVERALL_LI'])
df
# Out:
#         DISTNAME STATNAME  BLOCKS  VILLAGES  CLUSTERS  TOTPOPULAT  OVERALL_LI  \
# 0     DISTRICT32   STATE1      13       391       104    875564.0       66.92
# 1    DISTRICT649   STATE1      18       678       144   1015503.0       66.93
# 2    DISTRICT229   STATE1       8        94        65   1269751.0       71.21
# 3    DISTRICT259   STATE1      13       523       104    735753.0       57.98
# 4    DISTRICT486   STATE1       8       359        64    570060.0       65.00
# ..           ...      ...     ...       ...       ...         ...         ...
# 675  DISTRICT522  STATE29      37       876       137   5296396.0       78.05
# 676  DISTRICT498  STATE29      64      1458       230   4042191.0       56.06
# 677  DISTRICT343  STATE29      59      1117       216   3483648.0       65.05
# 678  DISTRICT130  STATE29      51       993       211   3522644.0       66.16
# 679  DISTRICT341  STATE29      41       783       185   2798214.0       65.46
#
#      Z_SCORE
# 0        NaN
# ...

# %%
df[(df['Z_SCORE'] > 3) | (df['Z_SCORE'] < -3)]
# Out:
# Empty DataFrame
# Columns: [DISTNAME, STATNAME, BLOCKS, VILLAGES, CLUSTERS, TOTPOPULAT, OVERALL_LI, Z_SCORE]
# Index: []

# %%
df3 = pd.read_csv("D:/Downloads/modified_c4_epa_air_quality.csv")
df3
# Out:
#      date_local            state_name           county_name      city_name  \
# 0    2018-01-01               Arizona              Maricopa        Buckeye
# 1    2018-01-01                  Ohio               Belmont      Shadyside
# 2    2018-01-01               Wyoming                 Teton  Not in a city
# 3    2018-01-01          Pennsylvania          Philadelphia   Philadelphia
# 4    2018-01-01                  Iowa                  Polk     Des Moines
# ..          ...                   ...                   ...            ...
# 255  2018-01-01  District Of Columbia  District of Columbia     Washington
# 256  2018-01-01             Wisconsin                 Dodge       Kekoskee
# 257  2018-01-01              Kentucky             Jefferson     Louisville
# 258  2018-01-01              Nebraska               Douglas          Omaha
# 259  2018-01-01        North Carolina                  Wake  Not in a city
#
# ...

# %%
df3['aqi_log'].hist()
# Out:
# <Axes: >

# %%
# Define variable for aqi_log standard deviation.

### YOUR CODE HERE ###



# Print out the mean.

### YOUR CODE HERE ###
mean_aqi_log = df3['aqi_log'].mean()
mean_aqi_log
# Out:
# np.float64(1.7669210929985582)

# %%
# Define variable for aqi_log standard deviation.

### YOUR CODE HERE ###



# Print out the standard deviation.

### YOUR CODE HERE ###
std_aqi_log = df3['aqi_log'].std()
std_aqi_log
# Out:
# 0.7147155520223721

# %%
#compute the actual percentage of district literacy rates that fall within +/- 1 SD from the mean.
lower_limit = mean_aqi_log - 1 * std_aqi_log
upper_limit = mean_aqi_log + 1 * std_aqi_log
((df3['aqi_log'] >= lower_limit) & (df3['aqi_log'] <= upper_limit)).mean()
# Out:
# np.float64(0.7615384615384615)

# %%
#percentage of values +/- 2 SD from mean
lower_limit = mean_aqi_log - 2 * std_aqi_log
upper_limit = mean_aqi_log + 2 * std_aqi_log
((df3['aqi_log'] >= lower_limit) & (df3['aqi_log'] <= upper_limit)).mean()
# Out:
# np.float64(0.9576923076923077)

# %%
#percentage of values +/- 3 SD from mean
lower_limit = mean_aqi_log - 3 * std_aqi_log
upper_limit = mean_aqi_log + 3 * std_aqi_log
((df3['aqi_log'] >= lower_limit) & (df3['aqi_log'] <= upper_limit)).mean()
# Out:
# np.float64(0.9961538461538462)

# %%
#comoute z-scores to find outliers
df3['Z_SCORE'] = stats.zscore(df3['aqi_log'])
df3
# Out:
#      date_local            state_name           county_name      city_name  \
# 0    2018-01-01               Arizona              Maricopa        Buckeye
# 1    2018-01-01                  Ohio               Belmont      Shadyside
# 2    2018-01-01               Wyoming                 Teton  Not in a city
# 3    2018-01-01          Pennsylvania          Philadelphia   Philadelphia
# 4    2018-01-01                  Iowa                  Polk     Des Moines
# ..          ...                   ...                   ...            ...
# 255  2018-01-01  District Of Columbia  District of Columbia     Washington
# 256  2018-01-01             Wisconsin                 Dodge       Kekoskee
# 257  2018-01-01              Kentucky             Jefferson     Louisville
# 258  2018-01-01              Nebraska               Douglas          Omaha
# 259  2018-01-01        North Carolina                  Wake  Not in a city
#
# ...

# %%
# Display data where `aqi_log` is above or below 3 standard deviations of the mean
df3[(df3["Z_SCORE"] > 3) | (df3["Z_SCORE"] < -3)]
# Out:
#      date_local state_name county_name city_name local_site_name  \
# 244  2018-01-01    Arizona    Maricopa   Phoenix    WEST PHOENIX
#
#       parameter_name   units_of_measure   aqi_log   Z_SCORE
# 244  Carbon monoxide  Parts per million  3.931826  3.034886
